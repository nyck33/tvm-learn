# %% [markdown]
# # Getting Starting using TVMC Python: a high-level API for TVM
# **Author**:
# [Jocelyn Shiue](https://github.com/CircleSpin)
#
# Hi! Here we explain the scripting tool designed for the complete TVM beginner. 🙂
#
# Before we get started let's get an example model if you don't already have one.
# Follow the steps to download a resnet model via the terminal:
#
# ```python
# mkdir myscripts
# cd myscripts
# wget https://github.com/onnx/models/raw/b9a54e89508f101a1611cd64f4ef56b9cb62c7cf/vision/classification/resnet/model/resnet50-v2-7.onnx
# mv resnet50-v2-7.onnx my_model.onnx
# touch tvmcpythonintro.py
# ```
# Let's start editing the python file in your favorite text editor.

# %% [markdown]
# ## Step 0: Imports
#
# ```python
# from tvm.driver import tvmc
# ```

# %%
from tvm.driver import tvmc

# %% [markdown]
# ## Step 1: Load a model
#
# Let's import our model into tvmc. This step converts a machine learning model from
# a supported framework into TVM's high level graph representation language called Relay.
# This is to have a unified starting point for all models in tvm. The frameworks we currently
# support are: Keras, ONNX, Tensorflow, TFLite, and PyTorch.
#
# ```python
# model = tvmc.load('my_model.onnx') #Step 1: Load
# ```
# If you'd like to see the Relay, you can run:
# ``model.summary()``
#
# All frameworks support overwriting the input shapes with a shape_dict argument.
# For most frameworks this is optional, but for Pytorch this is necessary as
# TVM cannot automatically search for it.
#
# ```python
# #model = tvmc.load('my_model.onnx', shape_dict={'input1' : [1, 2, 3, 4], 'input2' : [1, 2, 3, 4]}) #Step 1: Load + shape_dict
# ```
# A suggested way to see the model's input/shape_dict is via [netron](https://netron.app/). After opening the model,
# click the first node to see the name(s) and shape(s) in the inputs section.

# %%
! pwd
# Out:
# /mnt/d/TVM/tvm/tvm-tutorials

# %%
model = tvmc.load('resnet50-v2-7.onnx')
model.summary()
# Out:
# def @main(%data: Tensor[(1, 3, 224, 224), float32] /* ty=Tensor[(1, 3, 224, 224), float32] span=resnetv24_batchnorm0_fwd.data:0:0 */) -> Tensor[(1, 1000), float32] {
#   %0 = nn.batch_norm(%data, meta[relay.Constant][0] /* ty=Tensor[(3), float32] span=resnetv24_batchnorm0_fwd.resnetv24_batchnorm0_gamma:0:0 */, meta[relay.Constant][1] /* ty=Tensor[(3), float32] span=resnetv24_batchnorm0_fwd.resnetv24_batchnorm0_beta:0:0 */, meta[relay.Constant][2] /* ty=Tensor[(3), float32] span=resnetv24_batchnorm0_fwd.resnetv24_batchnorm0_running_mean:0:0 */, meta[relay.Constant][3] /* ty=Tensor[(3), float32] span=resnetv24_batchnorm0_fwd.resnetv24_batchnorm0_running_var:0:0 */) /* ty=(Tensor[(1, 3, 224, 224), float32], Tensor[(3), float32], Tensor[(3), float32]) span=resnetv24_batchnorm0_fwd:0:0 */;
#   %1 = %0.0 /* ty=Tensor[(1, 3, 224, 224), float32] span=resnetv24_batchnorm0_fwd:0:0 */;
#   %2 = nn.conv2d(%1, meta[relay.Constant][4] /* ty=Tensor[(64, 3, 7, 7), float32] span=resnetv24_conv0_fwd.resnetv24_conv0_weight:0:0 */, strides=[2, 2], padding=[3, 3, 3, 3], channels=64, kernel_size=[7, 7]) /* ty=Tensor[(1, 64, 112, 112), float32] span=resnetv24_conv0_fwd:0:0 */;
#   %3 = nn.batch_norm(%2, meta[relay.Constant][5] /* ty=Tensor[(64), float32] span=resnetv24_batchnorm1_fwd.resnetv24_batchnorm1_gamma:0:0 */, meta[relay.Constant][6] /* ty=Tensor[(64), float32] span=resnetv24_batchnorm1_fwd.resnetv24_batchnorm1_beta:0:0 */, meta[relay.Constant][7] /* ty=Tensor[(64), float32] span=resnetv24_batchnorm1_fwd.resnetv24_batchnorm1_running_mean:0:0 */, meta[relay.Constant][8] /* ty=Tensor[(64), float32] span=resnetv24_batchnorm1_fwd.resnetv24_batchnorm1_running_var:0:0 */) /* ty=(Tensor[(1, 64, 112, 112), float32], Tensor[(64), float32], Tensor[(64), float32]) span=resnetv24_batchnorm1_fwd:0:0 */;
#   %4 = %3.0 /* ty=Tensor[(1, 64, 112, 112), float32] span=resnetv24_batchnorm1_fwd:0:0 */;
#   %5 = nn.relu(%4) /* ty=Tensor[(1, 64, 112, 112), float32] span=resnetv24_relu0_fwd:0:0 */;
#   %6 = nn.max_pool2d(%5, pool_size=[3, 3], strides=[2, 2], padding=[1, 1, 1, 1]) /* ty=Tensor[(1, 64, 56, 56), float32] span=resnetv24_pool0_fwd:0:0 */;
#   %7 = nn.batch_norm(%6, meta[relay.Constant][9] /* ty=Tensor[(64), float32] span=resnetv24_stage1_batchnorm0_fwd.resnetv24_stage1_batchnorm0_gamma:0:0 */, meta[relay.Constant][10] /* ty=Tensor[(64), float32] span=resnetv24_stage1_batchnorm0_fwd.resnetv24_stage1_batchnorm0_beta:0:0 */, meta[relay.Constant][11] /* ty=Tensor[(64), float32] span=resnetv24_stage1_batchnorm0_fwd.resnetv24_stage1_batchnorm0_running_mean:0:0 */, meta[relay.Constant][12] /* ty=Tensor[(64), float32] span=resnetv24_stage1_batchnorm0_fwd.resnetv24_stage1_batchnorm0_running_var:0:0 */) /* ty=(Tensor[(1, 64, 56, 56), float32], Tensor[(64), float32], Tensor[(64), float32]) span=resnetv24_stage1_batchnorm0_fwd:0:0 */;
#   %8 = %7.0 /* ty=Tensor[(1, 64, 56, 56), float32] span=resnetv24_stage1_batchnorm0_fwd:0:0 */;
#   %9 = nn.relu(%8) /* ty=Tensor[(1, 64, 56, 56), float32] span=resnetv24_stage1_activation0:0:0 */;
#   %10 = nn.conv2d(%9, meta[relay.Constant][13] /* ty=Tensor[(64, 64, 1, 1), float32] span=resnetv24_stage1_conv0_fwd.resnetv24_stage1_conv0_weight:0:0 */, padding=[0, 0, 0, 0], channels=64, kernel_size=[1, 1]) /* ty=Tensor[(1, 64, 56, 56), float32] span=resnetv24_stage1_conv0_fwd:0:0 */;
#   %11 = nn.batch_norm(%10, meta[relay.Constant][14] /* ty=Tensor[(64), float32] span=resnetv24_stage1_batchnorm1_fwd.resnetv24_stage1_batchnorm1_gamma:0:0 */, meta[relay.Constant][15] /* ty=Tensor[(64), float32] span=resnetv24_stage1_batchnorm1_fwd.resnetv24_stage1_batchnorm1_beta:0:0 */, meta[relay.Constant][16] /* ty=Tensor[(64), float32] span=resnetv24_stage1_batchnorm1_fwd.resnetv24_stage1_batchnorm1_running_mean:0:0 */, meta[relay.Constant][17] /* ty=Tensor[(64), float32] span=resnetv24_stage1_batchnorm1_fwd.resnetv24_stage1_batchnorm1_running_var:0:0 */) /* ty=(Tensor[(1, 64, 56, 56), float32], Tensor[(64), float32], Tensor[(64), float32]) span=resnetv24_stage1_batchnorm1_fwd:0:0 */;
#   %12 = %11.0 /* ty=Tensor[(1, 64, 56, 56), float32] span=resnetv24_stage1_batchnorm1_fwd:0:0 */;
#   %13 = nn.relu(%12) /* ty=Tensor[(1, 64, 56, 56), float32] span=resnetv24_stage1_activation1:0:0 */;
#   %14 = nn.conv2d(%13, meta[relay.Constant][18] /* ty=Tensor[(64, 64, 3, 3), float32] span=resnetv24_stage1_conv1_fwd.resnetv24_stage1_conv1_weight:0:0 */, padding=[1, 1, 1, 1], channels=64, kernel_size=[3, 3]) /* ty=Tensor[(1, 64, 56, 56), float32] span=resnetv24_stage1_conv1_fwd:0:0 */;
#   %15 = nn.batch_norm(%14, meta[relay.Constant][19] /* ty=Tensor[(64), float32] span=resnetv24_stage1_batchnorm2_fwd.resnetv24_stage1_batchnorm2_gamma:0:0 */, meta[relay.Constant][20] /* ty=Tensor[(64), float32] span=resnetv24_stage1_batchnorm2_fwd.resnetv24_stage1_batchnorm2_beta:0:0 */, meta[relay.Constant][21] /* ty=Tensor[(64), float32] span=resnetv24_stage1_batchnorm2_fwd.resnetv24_stage1_batchnorm2_running_mean:0:0 */, meta[relay.Constant][22] /* ty=Tensor[(64), float32] span=resnetv24_stage1_batchnorm2_fwd.resnetv24_stage1_batchnorm2_running_var:0:0 */) /* ty=(Tensor[(1, 64, 56, 56), float32], Tensor[(64), float32], Tensor[(64), float32]) span=resnetv24_stage1_batchnorm2_fwd:0:0 */;
#   %16 = %15.0 /* ty=Tensor[(1, 64, 56, 56), float32] span=resnetv24_stage1_batchnorm2_fwd:0:0 */;
#   %17 = nn.relu(%16) /* ty=Tensor[(1, 64, 56, 56), float32] span=resnetv24_stage1_activation2:0:0 */;
#   %18 = nn.conv2d(%17, meta[relay.Constant][23] /* ty=Tensor[(256, 64, 1, 1), float32] span=resnetv24_stage1_conv2_fwd.resnetv24_stage1_conv2_weight:0:0 */, padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1]) /* ty=Tensor[(1, 256, 56, 56), float32] span=resnetv24_stage1_conv2_fwd:0:0 */;
#   %19 = nn.conv2d(%9, meta[relay.Constant][24] /* ty=Tensor[(256, 64, 1, 1), float32] span=resnetv24_stage1_conv3_fwd.resnetv24_stage1_conv3_weight:0:0 */, padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1]) /* ty=Tensor[(1, 256, 56, 56), float32] span=resnetv24_stage1_conv3_fwd:0:0 */;
#   %20 = add(%18, %19) /* ty=Tensor[(1, 256, 56, 56), float32] span=resnetv24_stage1__plus0:0:0 */;
#   %21 = nn.batch_norm(%20, meta[relay.Constant][25] /* ty=Tensor[(256), float32] span=resnetv24_stage1_batchnorm3_fwd.resnetv24_stage1_batchnorm3_gamma:0:0 */, meta[relay.Constant][26] /* ty=Tensor[(256), float32] span=resnetv24_stage1_batchnorm3_fwd.resnetv24_stage1_batchnorm3_beta:0:0 */, meta[relay.Constant][27] /* ty=Tensor[(256), float32] span=resnetv24_stage1_batchnorm3_fwd.resnetv24_stage1_batchnorm3_running_mean:0:0 */, meta[relay.Constant][28] /* ty=Tensor[(256), float32] span=resnetv24_stage1_batchnorm3_fwd.resnetv24_stage1_batchnorm3_running_var:0:0 */) /* ty=(Tensor[(1, 256, 56, 56), float32], Tensor[(256), float32], Tensor[(256), float32]) span=resnetv24_stage1_batchnorm3_fwd:0:0 */;
#   %22 = %21.0 /* ty=Tensor[(1, 256, 56, 56), float32] span=resnetv24_stage1_batchnorm3_fwd:0:0 */;
#   %23 = nn.relu(%22) /* ty=Tensor[(1, 256, 56, 56), float32] span=resnetv24_stage1_activation3:0:0 */;
#   %24 = nn.conv2d(%23, meta[relay.Constant][29] /* ty=Tensor[(64, 256, 1, 1), float32] span=resnetv24_stage1_conv4_fwd.resnetv24_stage1_conv4_weight:0:0 */, padding=[0, 0, 0, 0], channels=64, kernel_size=[1, 1]) /* ty=Tensor[(1, 64, 56, 56), float32] span=resnetv24_stage1_conv4_fwd:0:0 */;
#   %25 = nn.batch_norm(%24, meta[relay.Constant][30] /* ty=Tensor[(64), float32] span=resnetv24_stage1_batchnorm4_fwd.resnetv24_stage1_batchnorm4_gamma:0:0 */, meta[relay.Constant][31] /* ty=Tensor[(64), float32] span=resnetv24_stage1_batchnorm4_fwd.resnetv24_stage1_batchnorm4_beta:0:0 */, meta[relay.Constant][32] /* ty=Tensor[(64), float32] span=resnetv24_stage1_batchnorm4_fwd.resnetv24_stage1_batchnorm4_running_mean:0:0 */, meta[relay.Constant][33] /* ty=Tensor[(64), float32] span=resnetv24_stage1_batchnorm4_fwd.resnetv24_stage1_batchnorm4_running_var:0:0 */) /* ty=(Tensor[(1, 64, 56, 56), float32], Tensor[(64), float32], Tensor[(64), float32]) span=resnetv24_stage1_batchnorm4_fwd:0:0 */;
#   %26 = %25.0 /* ty=Tensor[(1, 64, 56, 56), float32] span=resnetv24_stage1_batchnorm4_fwd:0:0 */;
#   %27 = nn.relu(%26) /* ty=Tensor[(1, 64, 56, 56), float32] span=resnetv24_stage1_activation4:0:0 */;
#   %28 = nn.conv2d(%27, meta[relay.Constant][34] /* ty=Tensor[(64, 64, 3, 3), float32] span=resnetv24_stage1_conv5_fwd.resnetv24_stage1_conv5_weight:0:0 */, padding=[1, 1, 1, 1], channels=64, kernel_size=[3, 3]) /* ty=Tensor[(1, 64, 56, 56), float32] span=resnetv24_stage1_conv5_fwd:0:0 */;
#   %29 = nn.batch_norm(%28, meta[relay.Constant][35] /* ty=Tensor[(64), float32] span=resnetv24_stage1_batchnorm5_fwd.resnetv24_stage1_batchnorm5_gamma:0:0 */, meta[relay.Constant][36] /* ty=Tensor[(64), float32] span=resnetv24_stage1_batchnorm5_fwd.resnetv24_stage1_batchnorm5_beta:0:0 */, meta[relay.Constant][37] /* ty=Tensor[(64), float32] span=resnetv24_stage1_batchnorm5_fwd.resnetv24_stage1_batchnorm5_running_mean:0:0 */, meta[relay.Constant][38] /* ty=Tensor[(64), float32] span=resnetv24_stage1_batchnorm5_fwd.resnetv24_stage1_batchnorm5_running_var:0:0 */) /* ty=(Tensor[(1, 64, 56, 56), float32], Tensor[(64), float32], Tensor[(64), float32]) span=resnetv24_stage1_batchnorm5_fwd:0:0 */;
#   %30 = %29.0 /* ty=Tensor[(1, 64, 56, 56), float32] span=resnetv24_stage1_batchnorm5_fwd:0:0 */;
#   %31 = nn.relu(%30) /* ty=Tensor[(1, 64, 56, 56), float32] span=resnetv24_stage1_activation5:0:0 */;
#   %32 = nn.conv2d(%31, meta[relay.Constant][39] /* ty=Tensor[(256, 64, 1, 1), float32] span=resnetv24_stage1_conv6_fwd.resnetv24_stage1_conv6_weight:0:0 */, padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1]) /* ty=Tensor[(1, 256, 56, 56), float32] span=resnetv24_stage1_conv6_fwd:0:0 */;
#   %33 = add(%32, %20) /* ty=Tensor[(1, 256, 56, 56), float32] span=resnetv24_stage1__plus1:0:0 */;
#   %34 = nn.batch_norm(%33, meta[relay.Constant][40] /* ty=Tensor[(256), float32] span=resnetv24_stage1_batchnorm6_fwd.resnetv24_stage1_batchnorm6_gamma:0:0 */, meta[relay.Constant][41] /* ty=Tensor[(256), float32] span=resnetv24_stage1_batchnorm6_fwd.resnetv24_stage1_batchnorm6_beta:0:0 */, meta[relay.Constant][42] /* ty=Tensor[(256), float32] span=resnetv24_stage1_batchnorm6_fwd.resnetv24_stage1_batchnorm6_running_mean:0:0 */, meta[relay.Constant][43] /* ty=Tensor[(256), float32] span=resnetv24_stage1_batchnorm6_fwd.resnetv24_stage1_batchnorm6_running_var:0:0 */) /* ty=(Tensor[(1, 256, 56, 56), float32], Tensor[(256), float32], Tensor[(256), float32]) span=resnetv24_stage1_batchnorm6_fwd:0:0 */;
#   %35 = %34.0 /* ty=Tensor[(1, 256, 56, 56), float32] span=resnetv24_stage1_batchnorm6_fwd:0:0 */;
#   %36 = nn.relu(%35) /* ty=Tensor[(1, 256, 56, 56), float32] span=resnetv24_stage1_activation6:0:0 */;
#   %37 = nn.conv2d(%36, meta[relay.Constant][44] /* ty=Tensor[(64, 256, 1, 1), float32] span=resnetv24_stage1_conv7_fwd.resnetv24_stage1_conv7_weight:0:0 */, padding=[0, 0, 0, 0], channels=64, kernel_size=[1, 1]) /* ty=Tensor[(1, 64, 56, 56), float32] span=resnetv24_stage1_conv7_fwd:0:0 */;
#   %38 = nn.batch_norm(%37, meta[relay.Constant][45] /* ty=Tensor[(64), float32] span=resnetv24_stage1_batchnorm7_fwd.resnetv24_stage1_batchnorm7_gamma:0:0 */, meta[relay.Constant][46] /* ty=Tensor[(64), float32] span=resnetv24_stage1_batchnorm7_fwd.resnetv24_stage1_batchnorm7_beta:0:0 */, meta[relay.Constant][47] /* ty=Tensor[(64), float32] span=resnetv24_stage1_batchnorm7_fwd.resnetv24_stage1_batchnorm7_running_mean:0:0 */, meta[relay.Constant][48] /* ty=Tensor[(64), float32] span=resnetv24_stage1_batchnorm7_fwd.resnetv24_stage1_batchnorm7_running_var:0:0 */) /* ty=(Tensor[(1, 64, 56, 56), float32], Tensor[(64), float32], Tensor[(64), float32]) span=resnetv24_stage1_batchnorm7_fwd:0:0 */;
#   %39 = %38.0 /* ty=Tensor[(1, 64, 56, 56), float32] span=resnetv24_stage1_batchnorm7_fwd:0:0 */;
#   %40 = nn.relu(%39) /* ty=Tensor[(1, 64, 56, 56), float32] span=resnetv24_stage1_activation7:0:0 */;
#   %41 = nn.conv2d(%40, meta[relay.Constant][49] /* ty=Tensor[(64, 64, 3, 3), float32] span=resnetv24_stage1_conv8_fwd.resnetv24_stage1_conv8_weight:0:0 */, padding=[1, 1, 1, 1], channels=64, kernel_size=[3, 3]) /* ty=Tensor[(1, 64, 56, 56), float32] span=resnetv24_stage1_conv8_fwd:0:0 */;
#   %42 = nn.batch_norm(%41, meta[relay.Constant][50] /* ty=Tensor[(64), float32] span=resnetv24_stage1_batchnorm8_fwd.resnetv24_stage1_batchnorm8_gamma:0:0 */, meta[relay.Constant][51] /* ty=Tensor[(64), float32] span=resnetv24_stage1_batchnorm8_fwd.resnetv24_stage1_batchnorm8_beta:0:0 */, meta[relay.Constant][52] /* ty=Tensor[(64), float32] span=resnetv24_stage1_batchnorm8_fwd.resnetv24_stage1_batchnorm8_running_mean:0:0 */, meta[relay.Constant][53] /* ty=Tensor[(64), float32] span=resnetv24_stage1_batchnorm8_fwd.resnetv24_stage1_batchnorm8_running_var:0:0 */) /* ty=(Tensor[(1, 64, 56, 56), float32], Tensor[(64), float32], Tensor[(64), float32]) span=resnetv24_stage1_batchnorm8_fwd:0:0 */;
#   %43 = %42.0 /* ty=Tensor[(1, 64, 56, 56), float32] span=resnetv24_stage1_batchnorm8_fwd:0:0 */;
#   %44 = nn.relu(%43) /* ty=Tensor[(1, 64, 56, 56), float32] span=resnetv24_stage1_activation8:0:0 */;
#   %45 = nn.conv2d(%44, meta[relay.Constant][54] /* ty=Tensor[(256, 64, 1, 1), float32] span=resnetv24_stage1_conv9_fwd.resnetv24_stage1_conv9_weight:0:0 */, padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1]) /* ty=Tensor[(1, 256, 56, 56), float32] span=resnetv24_stage1_conv9_fwd:0:0 */;
#   %46 = add(%45, %33) /* ty=Tensor[(1, 256, 56, 56), float32] span=resnetv24_stage1__plus2:0:0 */;
#   %47 = nn.batch_norm(%46, meta[relay.Constant][55] /* ty=Tensor[(256), float32] span=resnetv24_stage2_batchnorm0_fwd.resnetv24_stage2_batchnorm0_gamma:0:0 */, meta[relay.Constant][56] /* ty=Tensor[(256), float32] span=resnetv24_stage2_batchnorm0_fwd.resnetv24_stage2_batchnorm0_beta:0:0 */, meta[relay.Constant][57] /* ty=Tensor[(256), float32] span=resnetv24_stage2_batchnorm0_fwd.resnetv24_stage2_batchnorm0_running_mean:0:0 */, meta[relay.Constant][58] /* ty=Tensor[(256), float32] span=resnetv24_stage2_batchnorm0_fwd.resnetv24_stage2_batchnorm0_running_var:0:0 */) /* ty=(Tensor[(1, 256, 56, 56), float32], Tensor[(256), float32], Tensor[(256), float32]) span=resnetv24_stage2_batchnorm0_fwd:0:0 */;
#   %48 = %47.0 /* ty=Tensor[(1, 256, 56, 56), float32] span=resnetv24_stage2_batchnorm0_fwd:0:0 */;
#   %49 = nn.relu(%48) /* ty=Tensor[(1, 256, 56, 56), float32] span=resnetv24_stage2_activation0:0:0 */;
#   %50 = nn.conv2d(%49, meta[relay.Constant][59] /* ty=Tensor[(128, 256, 1, 1), float32] span=resnetv24_stage2_conv0_fwd.resnetv24_stage2_conv0_weight:0:0 */, padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1]) /* ty=Tensor[(1, 128, 56, 56), float32] span=resnetv24_stage2_conv0_fwd:0:0 */;
#   %51 = nn.batch_norm(%50, meta[relay.Constant][60] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm1_fwd.resnetv24_stage2_batchnorm1_gamma:0:0 */, meta[relay.Constant][61] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm1_fwd.resnetv24_stage2_batchnorm1_beta:0:0 */, meta[relay.Constant][62] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm1_fwd.resnetv24_stage2_batchnorm1_running_mean:0:0 */, meta[relay.Constant][63] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm1_fwd.resnetv24_stage2_batchnorm1_running_var:0:0 */) /* ty=(Tensor[(1, 128, 56, 56), float32], Tensor[(128), float32], Tensor[(128), float32]) span=resnetv24_stage2_batchnorm1_fwd:0:0 */;
#   %52 = %51.0 /* ty=Tensor[(1, 128, 56, 56), float32] span=resnetv24_stage2_batchnorm1_fwd:0:0 */;
#   %53 = nn.relu(%52) /* ty=Tensor[(1, 128, 56, 56), float32] span=resnetv24_stage2_activation1:0:0 */;
#   %54 = nn.conv2d(%53, meta[relay.Constant][64] /* ty=Tensor[(128, 128, 3, 3), float32] span=resnetv24_stage2_conv1_fwd.resnetv24_stage2_conv1_weight:0:0 */, strides=[2, 2], padding=[1, 1, 1, 1], channels=128, kernel_size=[3, 3]) /* ty=Tensor[(1, 128, 28, 28), float32] span=resnetv24_stage2_conv1_fwd:0:0 */;
#   %55 = nn.batch_norm(%54, meta[relay.Constant][65] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm2_fwd.resnetv24_stage2_batchnorm2_gamma:0:0 */, meta[relay.Constant][66] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm2_fwd.resnetv24_stage2_batchnorm2_beta:0:0 */, meta[relay.Constant][67] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm2_fwd.resnetv24_stage2_batchnorm2_running_mean:0:0 */, meta[relay.Constant][68] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm2_fwd.resnetv24_stage2_batchnorm2_running_var:0:0 */) /* ty=(Tensor[(1, 128, 28, 28), float32], Tensor[(128), float32], Tensor[(128), float32]) span=resnetv24_stage2_batchnorm2_fwd:0:0 */;
#   %56 = %55.0 /* ty=Tensor[(1, 128, 28, 28), float32] span=resnetv24_stage2_batchnorm2_fwd:0:0 */;
#   %57 = nn.relu(%56) /* ty=Tensor[(1, 128, 28, 28), float32] span=resnetv24_stage2_activation2:0:0 */;
#   %58 = nn.conv2d(%57, meta[relay.Constant][69] /* ty=Tensor[(512, 128, 1, 1), float32] span=resnetv24_stage2_conv2_fwd.resnetv24_stage2_conv2_weight:0:0 */, padding=[0, 0, 0, 0], channels=512, kernel_size=[1, 1]) /* ty=Tensor[(1, 512, 28, 28), float32] span=resnetv24_stage2_conv2_fwd:0:0 */;
#   %59 = nn.conv2d(%49, meta[relay.Constant][70] /* ty=Tensor[(512, 256, 1, 1), float32] span=resnetv24_stage2_conv3_fwd.resnetv24_stage2_conv3_weight:0:0 */, strides=[2, 2], padding=[0, 0, 0, 0], channels=512, kernel_size=[1, 1]) /* ty=Tensor[(1, 512, 28, 28), float32] span=resnetv24_stage2_conv3_fwd:0:0 */;
#   %60 = add(%58, %59) /* ty=Tensor[(1, 512, 28, 28), float32] span=resnetv24_stage2__plus0:0:0 */;
#   %61 = nn.batch_norm(%60, meta[relay.Constant][71] /* ty=Tensor[(512), float32] span=resnetv24_stage2_batchnorm3_fwd.resnetv24_stage2_batchnorm3_gamma:0:0 */, meta[relay.Constant][72] /* ty=Tensor[(512), float32] span=resnetv24_stage2_batchnorm3_fwd.resnetv24_stage2_batchnorm3_beta:0:0 */, meta[relay.Constant][73] /* ty=Tensor[(512), float32] span=resnetv24_stage2_batchnorm3_fwd.resnetv24_stage2_batchnorm3_running_mean:0:0 */, meta[relay.Constant][74] /* ty=Tensor[(512), float32] span=resnetv24_stage2_batchnorm3_fwd.resnetv24_stage2_batchnorm3_running_var:0:0 */) /* ty=(Tensor[(1, 512, 28, 28), float32], Tensor[(512), float32], Tensor[(512), float32]) span=resnetv24_stage2_batchnorm3_fwd:0:0 */;
#   %62 = %61.0 /* ty=Tensor[(1, 512, 28, 28), float32] span=resnetv24_stage2_batchnorm3_fwd:0:0 */;
#   %63 = nn.relu(%62) /* ty=Tensor[(1, 512, 28, 28), float32] span=resnetv24_stage2_activation3:0:0 */;
#   %64 = nn.conv2d(%63, meta[relay.Constant][75] /* ty=Tensor[(128, 512, 1, 1), float32] span=resnetv24_stage2_conv4_fwd.resnetv24_stage2_conv4_weight:0:0 */, padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1]) /* ty=Tensor[(1, 128, 28, 28), float32] span=resnetv24_stage2_conv4_fwd:0:0 */;
#   %65 = nn.batch_norm(%64, meta[relay.Constant][76] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm4_fwd.resnetv24_stage2_batchnorm4_gamma:0:0 */, meta[relay.Constant][77] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm4_fwd.resnetv24_stage2_batchnorm4_beta:0:0 */, meta[relay.Constant][78] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm4_fwd.resnetv24_stage2_batchnorm4_running_mean:0:0 */, meta[relay.Constant][79] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm4_fwd.resnetv24_stage2_batchnorm4_running_var:0:0 */) /* ty=(Tensor[(1, 128, 28, 28), float32], Tensor[(128), float32], Tensor[(128), float32]) span=resnetv24_stage2_batchnorm4_fwd:0:0 */;
#   %66 = %65.0 /* ty=Tensor[(1, 128, 28, 28), float32] span=resnetv24_stage2_batchnorm4_fwd:0:0 */;
#   %67 = nn.relu(%66) /* ty=Tensor[(1, 128, 28, 28), float32] span=resnetv24_stage2_activation4:0:0 */;
#   %68 = nn.conv2d(%67, meta[relay.Constant][80] /* ty=Tensor[(128, 128, 3, 3), float32] span=resnetv24_stage2_conv5_fwd.resnetv24_stage2_conv5_weight:0:0 */, padding=[1, 1, 1, 1], channels=128, kernel_size=[3, 3]) /* ty=Tensor[(1, 128, 28, 28), float32] span=resnetv24_stage2_conv5_fwd:0:0 */;
#   %69 = nn.batch_norm(%68, meta[relay.Constant][81] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm5_fwd.resnetv24_stage2_batchnorm5_gamma:0:0 */, meta[relay.Constant][82] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm5_fwd.resnetv24_stage2_batchnorm5_beta:0:0 */, meta[relay.Constant][83] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm5_fwd.resnetv24_stage2_batchnorm5_running_mean:0:0 */, meta[relay.Constant][84] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm5_fwd.resnetv24_stage2_batchnorm5_running_var:0:0 */) /* ty=(Tensor[(1, 128, 28, 28), float32], Tensor[(128), float32], Tensor[(128), float32]) span=resnetv24_stage2_batchnorm5_fwd:0:0 */;
#   %70 = %69.0 /* ty=Tensor[(1, 128, 28, 28), float32] span=resnetv24_stage2_batchnorm5_fwd:0:0 */;
#   %71 = nn.relu(%70) /* ty=Tensor[(1, 128, 28, 28), float32] span=resnetv24_stage2_activation5:0:0 */;
#   %72 = nn.conv2d(%71, meta[relay.Constant][85] /* ty=Tensor[(512, 128, 1, 1), float32] span=resnetv24_stage2_conv6_fwd.resnetv24_stage2_conv6_weight:0:0 */, padding=[0, 0, 0, 0], channels=512, kernel_size=[1, 1]) /* ty=Tensor[(1, 512, 28, 28), float32] span=resnetv24_stage2_conv6_fwd:0:0 */;
#   %73 = add(%72, %60) /* ty=Tensor[(1, 512, 28, 28), float32] span=resnetv24_stage2__plus1:0:0 */;
#   %74 = nn.batch_norm(%73, meta[relay.Constant][86] /* ty=Tensor[(512), float32] span=resnetv24_stage2_batchnorm6_fwd.resnetv24_stage2_batchnorm6_gamma:0:0 */, meta[relay.Constant][87] /* ty=Tensor[(512), float32] span=resnetv24_stage2_batchnorm6_fwd.resnetv24_stage2_batchnorm6_beta:0:0 */, meta[relay.Constant][88] /* ty=Tensor[(512), float32] span=resnetv24_stage2_batchnorm6_fwd.resnetv24_stage2_batchnorm6_running_mean:0:0 */, meta[relay.Constant][89] /* ty=Tensor[(512), float32] span=resnetv24_stage2_batchnorm6_fwd.resnetv24_stage2_batchnorm6_running_var:0:0 */) /* ty=(Tensor[(1, 512, 28, 28), float32], Tensor[(512), float32], Tensor[(512), float32]) span=resnetv24_stage2_batchnorm6_fwd:0:0 */;
#   %75 = %74.0 /* ty=Tensor[(1, 512, 28, 28), float32] span=resnetv24_stage2_batchnorm6_fwd:0:0 */;
#   %76 = nn.relu(%75) /* ty=Tensor[(1, 512, 28, 28), float32] span=resnetv24_stage2_activation6:0:0 */;
#   %77 = nn.conv2d(%76, meta[relay.Constant][90] /* ty=Tensor[(128, 512, 1, 1), float32] span=resnetv24_stage2_conv7_fwd.resnetv24_stage2_conv7_weight:0:0 */, padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1]) /* ty=Tensor[(1, 128, 28, 28), float32] span=resnetv24_stage2_conv7_fwd:0:0 */;
#   %78 = nn.batch_norm(%77, meta[relay.Constant][91] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm7_fwd.resnetv24_stage2_batchnorm7_gamma:0:0 */, meta[relay.Constant][92] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm7_fwd.resnetv24_stage2_batchnorm7_beta:0:0 */, meta[relay.Constant][93] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm7_fwd.resnetv24_stage2_batchnorm7_running_mean:0:0 */, meta[relay.Constant][94] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm7_fwd.resnetv24_stage2_batchnorm7_running_var:0:0 */) /* ty=(Tensor[(1, 128, 28, 28), float32], Tensor[(128), float32], Tensor[(128), float32]) span=resnetv24_stage2_batchnorm7_fwd:0:0 */;
#   %79 = %78.0 /* ty=Tensor[(1, 128, 28, 28), float32] span=resnetv24_stage2_batchnorm7_fwd:0:0 */;
#   %80 = nn.relu(%79) /* ty=Tensor[(1, 128, 28, 28), float32] span=resnetv24_stage2_activation7:0:0 */;
#   %81 = nn.conv2d(%80, meta[relay.Constant][95] /* ty=Tensor[(128, 128, 3, 3), float32] span=resnetv24_stage2_conv8_fwd.resnetv24_stage2_conv8_weight:0:0 */, padding=[1, 1, 1, 1], channels=128, kernel_size=[3, 3]) /* ty=Tensor[(1, 128, 28, 28), float32] span=resnetv24_stage2_conv8_fwd:0:0 */;
#   %82 = nn.batch_norm(%81, meta[relay.Constant][96] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm8_fwd.resnetv24_stage2_batchnorm8_gamma:0:0 */, meta[relay.Constant][97] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm8_fwd.resnetv24_stage2_batchnorm8_beta:0:0 */, meta[relay.Constant][98] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm8_fwd.resnetv24_stage2_batchnorm8_running_mean:0:0 */, meta[relay.Constant][99] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm8_fwd.resnetv24_stage2_batchnorm8_running_var:0:0 */) /* ty=(Tensor[(1, 128, 28, 28), float32], Tensor[(128), float32], Tensor[(128), float32]) span=resnetv24_stage2_batchnorm8_fwd:0:0 */;
#   %83 = %82.0 /* ty=Tensor[(1, 128, 28, 28), float32] span=resnetv24_stage2_batchnorm8_fwd:0:0 */;
#   %84 = nn.relu(%83) /* ty=Tensor[(1, 128, 28, 28), float32] span=resnetv24_stage2_activation8:0:0 */;
#   %85 = nn.conv2d(%84, meta[relay.Constant][100] /* ty=Tensor[(512, 128, 1, 1), float32] span=resnetv24_stage2_conv9_fwd.resnetv24_stage2_conv9_weight:0:0 */, padding=[0, 0, 0, 0], channels=512, kernel_size=[1, 1]) /* ty=Tensor[(1, 512, 28, 28), float32] span=resnetv24_stage2_conv9_fwd:0:0 */;
#   %86 = add(%85, %73) /* ty=Tensor[(1, 512, 28, 28), float32] span=resnetv24_stage2__plus2:0:0 */;
#   %87 = nn.batch_norm(%86, meta[relay.Constant][101] /* ty=Tensor[(512), float32] span=resnetv24_stage2_batchnorm9_fwd.resnetv24_stage2_batchnorm9_gamma:0:0 */, meta[relay.Constant][102] /* ty=Tensor[(512), float32] span=resnetv24_stage2_batchnorm9_fwd.resnetv24_stage2_batchnorm9_beta:0:0 */, meta[relay.Constant][103] /* ty=Tensor[(512), float32] span=resnetv24_stage2_batchnorm9_fwd.resnetv24_stage2_batchnorm9_running_mean:0:0 */, meta[relay.Constant][104] /* ty=Tensor[(512), float32] span=resnetv24_stage2_batchnorm9_fwd.resnetv24_stage2_batchnorm9_running_var:0:0 */) /* ty=(Tensor[(1, 512, 28, 28), float32], Tensor[(512), float32], Tensor[(512), float32]) span=resnetv24_stage2_batchnorm9_fwd:0:0 */;
#   %88 = %87.0 /* ty=Tensor[(1, 512, 28, 28), float32] span=resnetv24_stage2_batchnorm9_fwd:0:0 */;
#   %89 = nn.relu(%88) /* ty=Tensor[(1, 512, 28, 28), float32] span=resnetv24_stage2_activation9:0:0 */;
#   %90 = nn.conv2d(%89, meta[relay.Constant][105] /* ty=Tensor[(128, 512, 1, 1), float32] span=resnetv24_stage2_conv10_fwd.resnetv24_stage2_conv10_weight:0:0 */, padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1]) /* ty=Tensor[(1, 128, 28, 28), float32] span=resnetv24_stage2_conv10_fwd:0:0 */;
#   %91 = nn.batch_norm(%90, meta[relay.Constant][106] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm10_fwd.resnetv24_stage2_batchnorm10_gamma:0:0 */, meta[relay.Constant][107] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm10_fwd.resnetv24_stage2_batchnorm10_beta:0:0 */, meta[relay.Constant][108] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm10_fwd.resnetv24_stage2_batchnorm10_running_mean:0:0 */, meta[relay.Constant][109] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm10_fwd.resnetv24_stage2_batchnorm10_running_var:0:0 */) /* ty=(Tensor[(1, 128, 28, 28), float32], Tensor[(128), float32], Tensor[(128), float32]) span=resnetv24_stage2_batchnorm10_fwd:0:0 */;
#   %92 = %91.0 /* ty=Tensor[(1, 128, 28, 28), float32] span=resnetv24_stage2_batchnorm10_fwd:0:0 */;
#   %93 = nn.relu(%92) /* ty=Tensor[(1, 128, 28, 28), float32] span=resnetv24_stage2_activation10:0:0 */;
#   %94 = nn.conv2d(%93, meta[relay.Constant][110] /* ty=Tensor[(128, 128, 3, 3), float32] span=resnetv24_stage2_conv11_fwd.resnetv24_stage2_conv11_weight:0:0 */, padding=[1, 1, 1, 1], channels=128, kernel_size=[3, 3]) /* ty=Tensor[(1, 128, 28, 28), float32] span=resnetv24_stage2_conv11_fwd:0:0 */;
#   %95 = nn.batch_norm(%94, meta[relay.Constant][111] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm11_fwd.resnetv24_stage2_batchnorm11_gamma:0:0 */, meta[relay.Constant][112] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm11_fwd.resnetv24_stage2_batchnorm11_beta:0:0 */, meta[relay.Constant][113] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm11_fwd.resnetv24_stage2_batchnorm11_running_mean:0:0 */, meta[relay.Constant][114] /* ty=Tensor[(128), float32] span=resnetv24_stage2_batchnorm11_fwd.resnetv24_stage2_batchnorm11_running_var:0:0 */) /* ty=(Tensor[(1, 128, 28, 28), float32], Tensor[(128), float32], Tensor[(128), float32]) span=resnetv24_stage2_batchnorm11_fwd:0:0 */;
#   %96 = %95.0 /* ty=Tensor[(1, 128, 28, 28), float32] span=resnetv24_stage2_batchnorm11_fwd:0:0 */;
#   %97 = nn.relu(%96) /* ty=Tensor[(1, 128, 28, 28), float32] span=resnetv24_stage2_activation11:0:0 */;
#   %98 = nn.conv2d(%97, meta[relay.Constant][115] /* ty=Tensor[(512, 128, 1, 1), float32] span=resnetv24_stage2_conv12_fwd.resnetv24_stage2_conv12_weight:0:0 */, padding=[0, 0, 0, 0], channels=512, kernel_size=[1, 1]) /* ty=Tensor[(1, 512, 28, 28), float32] span=resnetv24_stage2_conv12_fwd:0:0 */;
#   %99 = add(%98, %86) /* ty=Tensor[(1, 512, 28, 28), float32] span=resnetv24_stage2__plus3:0:0 */;
#   %100 = nn.batch_norm(%99, meta[relay.Constant][116] /* ty=Tensor[(512), float32] span=resnetv24_stage3_batchnorm0_fwd.resnetv24_stage3_batchnorm0_gamma:0:0 */, meta[relay.Constant][117] /* ty=Tensor[(512), float32] span=resnetv24_stage3_batchnorm0_fwd.resnetv24_stage3_batchnorm0_beta:0:0 */, meta[relay.Constant][118] /* ty=Tensor[(512), float32] span=resnetv24_stage3_batchnorm0_fwd.resnetv24_stage3_batchnorm0_running_mean:0:0 */, meta[relay.Constant][119] /* ty=Tensor[(512), float32] span=resnetv24_stage3_batchnorm0_fwd.resnetv24_stage3_batchnorm0_running_var:0:0 */) /* ty=(Tensor[(1, 512, 28, 28), float32], Tensor[(512), float32], Tensor[(512), float32]) span=resnetv24_stage3_batchnorm0_fwd:0:0 */;
#   %101 = %100.0 /* ty=Tensor[(1, 512, 28, 28), float32] span=resnetv24_stage3_batchnorm0_fwd:0:0 */;
#   %102 = nn.relu(%101) /* ty=Tensor[(1, 512, 28, 28), float32] span=resnetv24_stage3_activation0:0:0 */;
#   %103 = nn.conv2d(%102, meta[relay.Constant][120] /* ty=Tensor[(256, 512, 1, 1), float32] span=resnetv24_stage3_conv0_fwd.resnetv24_stage3_conv0_weight:0:0 */, padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1]) /* ty=Tensor[(1, 256, 28, 28), float32] span=resnetv24_stage3_conv0_fwd:0:0 */;
#   %104 = nn.batch_norm(%103, meta[relay.Constant][121] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm1_fwd.resnetv24_stage3_batchnorm1_gamma:0:0 */, meta[relay.Constant][122] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm1_fwd.resnetv24_stage3_batchnorm1_beta:0:0 */, meta[relay.Constant][123] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm1_fwd.resnetv24_stage3_batchnorm1_running_mean:0:0 */, meta[relay.Constant][124] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm1_fwd.resnetv24_stage3_batchnorm1_running_var:0:0 */) /* ty=(Tensor[(1, 256, 28, 28), float32], Tensor[(256), float32], Tensor[(256), float32]) span=resnetv24_stage3_batchnorm1_fwd:0:0 */;
#   %105 = %104.0 /* ty=Tensor[(1, 256, 28, 28), float32] span=resnetv24_stage3_batchnorm1_fwd:0:0 */;
#   %106 = nn.relu(%105) /* ty=Tensor[(1, 256, 28, 28), float32] span=resnetv24_stage3_activation1:0:0 */;
#   %107 = nn.conv2d(%106, meta[relay.Constant][125] /* ty=Tensor[(256, 256, 3, 3), float32] span=resnetv24_stage3_conv1_fwd.resnetv24_stage3_conv1_weight:0:0 */, strides=[2, 2], padding=[1, 1, 1, 1], channels=256, kernel_size=[3, 3]) /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_conv1_fwd:0:0 */;
#   %108 = nn.batch_norm(%107, meta[relay.Constant][126] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm2_fwd.resnetv24_stage3_batchnorm2_gamma:0:0 */, meta[relay.Constant][127] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm2_fwd.resnetv24_stage3_batchnorm2_beta:0:0 */, meta[relay.Constant][128] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm2_fwd.resnetv24_stage3_batchnorm2_running_mean:0:0 */, meta[relay.Constant][129] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm2_fwd.resnetv24_stage3_batchnorm2_running_var:0:0 */) /* ty=(Tensor[(1, 256, 14, 14), float32], Tensor[(256), float32], Tensor[(256), float32]) span=resnetv24_stage3_batchnorm2_fwd:0:0 */;
#   %109 = %108.0 /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_batchnorm2_fwd:0:0 */;
#   %110 = nn.relu(%109) /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_activation2:0:0 */;
#   %111 = nn.conv2d(%110, meta[relay.Constant][130] /* ty=Tensor[(1024, 256, 1, 1), float32] span=resnetv24_stage3_conv2_fwd.resnetv24_stage3_conv2_weight:0:0 */, padding=[0, 0, 0, 0], channels=1024, kernel_size=[1, 1]) /* ty=Tensor[(1, 1024, 14, 14), float32] span=resnetv24_stage3_conv2_fwd:0:0 */;
#   %112 = nn.conv2d(%102, meta[relay.Constant][131] /* ty=Tensor[(1024, 512, 1, 1), float32] span=resnetv24_stage3_conv3_fwd.resnetv24_stage3_conv3_weight:0:0 */, strides=[2, 2], padding=[0, 0, 0, 0], channels=1024, kernel_size=[1, 1]) /* ty=Tensor[(1, 1024, 14, 14), float32] span=resnetv24_stage3_conv3_fwd:0:0 */;
#   %113 = add(%111, %112) /* ty=Tensor[(1, 1024, 14, 14), float32] span=resnetv24_stage3__plus0:0:0 */;
#   %114 = nn.batch_norm(%113, meta[relay.Constant][132] /* ty=Tensor[(1024), float32] span=resnetv24_stage3_batchnorm3_fwd.resnetv24_stage3_batchnorm3_gamma:0:0 */, meta[relay.Constant][133] /* ty=Tensor[(1024), float32] span=resnetv24_stage3_batchnorm3_fwd.resnetv24_stage3_batchnorm3_beta:0:0 */, meta[relay.Constant][134] /* ty=Tensor[(1024), float32] span=resnetv24_stage3_batchnorm3_fwd.resnetv24_stage3_batchnorm3_running_mean:0:0 */, meta[relay.Constant][135] /* ty=Tensor[(1024), float32] span=resnetv24_stage3_batchnorm3_fwd.resnetv24_stage3_batchnorm3_running_var:0:0 */) /* ty=(Tensor[(1, 1024, 14, 14), float32], Tensor[(1024), float32], Tensor[(1024), float32]) span=resnetv24_stage3_batchnorm3_fwd:0:0 */;
#   %115 = %114.0 /* ty=Tensor[(1, 1024, 14, 14), float32] span=resnetv24_stage3_batchnorm3_fwd:0:0 */;
#   %116 = nn.relu(%115) /* ty=Tensor[(1, 1024, 14, 14), float32] span=resnetv24_stage3_activation3:0:0 */;
#   %117 = nn.conv2d(%116, meta[relay.Constant][136] /* ty=Tensor[(256, 1024, 1, 1), float32] span=resnetv24_stage3_conv4_fwd.resnetv24_stage3_conv4_weight:0:0 */, padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1]) /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_conv4_fwd:0:0 */;
#   %118 = nn.batch_norm(%117, meta[relay.Constant][137] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm4_fwd.resnetv24_stage3_batchnorm4_gamma:0:0 */, meta[relay.Constant][138] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm4_fwd.resnetv24_stage3_batchnorm4_beta:0:0 */, meta[relay.Constant][139] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm4_fwd.resnetv24_stage3_batchnorm4_running_mean:0:0 */, meta[relay.Constant][140] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm4_fwd.resnetv24_stage3_batchnorm4_running_var:0:0 */) /* ty=(Tensor[(1, 256, 14, 14), float32], Tensor[(256), float32], Tensor[(256), float32]) span=resnetv24_stage3_batchnorm4_fwd:0:0 */;
#   %119 = %118.0 /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_batchnorm4_fwd:0:0 */;
#   %120 = nn.relu(%119) /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_activation4:0:0 */;
#   %121 = nn.conv2d(%120, meta[relay.Constant][141] /* ty=Tensor[(256, 256, 3, 3), float32] span=resnetv24_stage3_conv5_fwd.resnetv24_stage3_conv5_weight:0:0 */, padding=[1, 1, 1, 1], channels=256, kernel_size=[3, 3]) /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_conv5_fwd:0:0 */;
#   %122 = nn.batch_norm(%121, meta[relay.Constant][142] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm5_fwd.resnetv24_stage3_batchnorm5_gamma:0:0 */, meta[relay.Constant][143] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm5_fwd.resnetv24_stage3_batchnorm5_beta:0:0 */, meta[relay.Constant][144] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm5_fwd.resnetv24_stage3_batchnorm5_running_mean:0:0 */, meta[relay.Constant][145] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm5_fwd.resnetv24_stage3_batchnorm5_running_var:0:0 */) /* ty=(Tensor[(1, 256, 14, 14), float32], Tensor[(256), float32], Tensor[(256), float32]) span=resnetv24_stage3_batchnorm5_fwd:0:0 */;
#   %123 = %122.0 /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_batchnorm5_fwd:0:0 */;
#   %124 = nn.relu(%123) /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_activation5:0:0 */;
#   %125 = nn.conv2d(%124, meta[relay.Constant][146] /* ty=Tensor[(1024, 256, 1, 1), float32] span=resnetv24_stage3_conv6_fwd.resnetv24_stage3_conv6_weight:0:0 */, padding=[0, 0, 0, 0], channels=1024, kernel_size=[1, 1]) /* ty=Tensor[(1, 1024, 14, 14), float32] span=resnetv24_stage3_conv6_fwd:0:0 */;
#   %126 = add(%125, %113) /* ty=Tensor[(1, 1024, 14, 14), float32] span=resnetv24_stage3__plus1:0:0 */;
#   %127 = nn.batch_norm(%126, meta[relay.Constant][147] /* ty=Tensor[(1024), float32] span=resnetv24_stage3_batchnorm6_fwd.resnetv24_stage3_batchnorm6_gamma:0:0 */, meta[relay.Constant][148] /* ty=Tensor[(1024), float32] span=resnetv24_stage3_batchnorm6_fwd.resnetv24_stage3_batchnorm6_beta:0:0 */, meta[relay.Constant][149] /* ty=Tensor[(1024), float32] span=resnetv24_stage3_batchnorm6_fwd.resnetv24_stage3_batchnorm6_running_mean:0:0 */, meta[relay.Constant][150] /* ty=Tensor[(1024), float32] span=resnetv24_stage3_batchnorm6_fwd.resnetv24_stage3_batchnorm6_running_var:0:0 */) /* ty=(Tensor[(1, 1024, 14, 14), float32], Tensor[(1024), float32], Tensor[(1024), float32]) span=resnetv24_stage3_batchnorm6_fwd:0:0 */;
#   %128 = %127.0 /* ty=Tensor[(1, 1024, 14, 14), float32] span=resnetv24_stage3_batchnorm6_fwd:0:0 */;
#   %129 = nn.relu(%128) /* ty=Tensor[(1, 1024, 14, 14), float32] span=resnetv24_stage3_activation6:0:0 */;
#   %130 = nn.conv2d(%129, meta[relay.Constant][151] /* ty=Tensor[(256, 1024, 1, 1), float32] span=resnetv24_stage3_conv7_fwd.resnetv24_stage3_conv7_weight:0:0 */, padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1]) /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_conv7_fwd:0:0 */;
#   %131 = nn.batch_norm(%130, meta[relay.Constant][152] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm7_fwd.resnetv24_stage3_batchnorm7_gamma:0:0 */, meta[relay.Constant][153] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm7_fwd.resnetv24_stage3_batchnorm7_beta:0:0 */, meta[relay.Constant][154] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm7_fwd.resnetv24_stage3_batchnorm7_running_mean:0:0 */, meta[relay.Constant][155] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm7_fwd.resnetv24_stage3_batchnorm7_running_var:0:0 */) /* ty=(Tensor[(1, 256, 14, 14), float32], Tensor[(256), float32], Tensor[(256), float32]) span=resnetv24_stage3_batchnorm7_fwd:0:0 */;
#   %132 = %131.0 /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_batchnorm7_fwd:0:0 */;
#   %133 = nn.relu(%132) /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_activation7:0:0 */;
#   %134 = nn.conv2d(%133, meta[relay.Constant][156] /* ty=Tensor[(256, 256, 3, 3), float32] span=resnetv24_stage3_conv8_fwd.resnetv24_stage3_conv8_weight:0:0 */, padding=[1, 1, 1, 1], channels=256, kernel_size=[3, 3]) /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_conv8_fwd:0:0 */;
#   %135 = nn.batch_norm(%134, meta[relay.Constant][157] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm8_fwd.resnetv24_stage3_batchnorm8_gamma:0:0 */, meta[relay.Constant][158] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm8_fwd.resnetv24_stage3_batchnorm8_beta:0:0 */, meta[relay.Constant][159] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm8_fwd.resnetv24_stage3_batchnorm8_running_mean:0:0 */, meta[relay.Constant][160] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm8_fwd.resnetv24_stage3_batchnorm8_running_var:0:0 */) /* ty=(Tensor[(1, 256, 14, 14), float32], Tensor[(256), float32], Tensor[(256), float32]) span=resnetv24_stage3_batchnorm8_fwd:0:0 */;
#   %136 = %135.0 /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_batchnorm8_fwd:0:0 */;
#   %137 = nn.relu(%136) /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_activation8:0:0 */;
#   %138 = nn.conv2d(%137, meta[relay.Constant][161] /* ty=Tensor[(1024, 256, 1, 1), float32] span=resnetv24_stage3_conv9_fwd.resnetv24_stage3_conv9_weight:0:0 */, padding=[0, 0, 0, 0], channels=1024, kernel_size=[1, 1]) /* ty=Tensor[(1, 1024, 14, 14), float32] span=resnetv24_stage3_conv9_fwd:0:0 */;
#   %139 = add(%138, %126) /* ty=Tensor[(1, 1024, 14, 14), float32] span=resnetv24_stage3__plus2:0:0 */;
#   %140 = nn.batch_norm(%139, meta[relay.Constant][162] /* ty=Tensor[(1024), float32] span=resnetv24_stage3_batchnorm9_fwd.resnetv24_stage3_batchnorm9_gamma:0:0 */, meta[relay.Constant][163] /* ty=Tensor[(1024), float32] span=resnetv24_stage3_batchnorm9_fwd.resnetv24_stage3_batchnorm9_beta:0:0 */, meta[relay.Constant][164] /* ty=Tensor[(1024), float32] span=resnetv24_stage3_batchnorm9_fwd.resnetv24_stage3_batchnorm9_running_mean:0:0 */, meta[relay.Constant][165] /* ty=Tensor[(1024), float32] span=resnetv24_stage3_batchnorm9_fwd.resnetv24_stage3_batchnorm9_running_var:0:0 */) /* ty=(Tensor[(1, 1024, 14, 14), float32], Tensor[(1024), float32], Tensor[(1024), float32]) span=resnetv24_stage3_batchnorm9_fwd:0:0 */;
#   %141 = %140.0 /* ty=Tensor[(1, 1024, 14, 14), float32] span=resnetv24_stage3_batchnorm9_fwd:0:0 */;
#   %142 = nn.relu(%141) /* ty=Tensor[(1, 1024, 14, 14), float32] span=resnetv24_stage3_activation9:0:0 */;
#   %143 = nn.conv2d(%142, meta[relay.Constant][166] /* ty=Tensor[(256, 1024, 1, 1), float32] span=resnetv24_stage3_conv10_fwd.resnetv24_stage3_conv10_weight:0:0 */, padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1]) /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_conv10_fwd:0:0 */;
#   %144 = nn.batch_norm(%143, meta[relay.Constant][167] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm10_fwd.resnetv24_stage3_batchnorm10_gamma:0:0 */, meta[relay.Constant][168] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm10_fwd.resnetv24_stage3_batchnorm10_beta:0:0 */, meta[relay.Constant][169] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm10_fwd.resnetv24_stage3_batchnorm10_running_mean:0:0 */, meta[relay.Constant][170] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm10_fwd.resnetv24_stage3_batchnorm10_running_var:0:0 */) /* ty=(Tensor[(1, 256, 14, 14), float32], Tensor[(256), float32], Tensor[(256), float32]) span=resnetv24_stage3_batchnorm10_fwd:0:0 */;
#   %145 = %144.0 /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_batchnorm10_fwd:0:0 */;
#   %146 = nn.relu(%145) /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_activation10:0:0 */;
#   %147 = nn.conv2d(%146, meta[relay.Constant][171] /* ty=Tensor[(256, 256, 3, 3), float32] span=resnetv24_stage3_conv11_fwd.resnetv24_stage3_conv11_weight:0:0 */, padding=[1, 1, 1, 1], channels=256, kernel_size=[3, 3]) /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_conv11_fwd:0:0 */;
#   %148 = nn.batch_norm(%147, meta[relay.Constant][172] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm11_fwd.resnetv24_stage3_batchnorm11_gamma:0:0 */, meta[relay.Constant][173] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm11_fwd.resnetv24_stage3_batchnorm11_beta:0:0 */, meta[relay.Constant][174] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm11_fwd.resnetv24_stage3_batchnorm11_running_mean:0:0 */, meta[relay.Constant][175] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm11_fwd.resnetv24_stage3_batchnorm11_running_var:0:0 */) /* ty=(Tensor[(1, 256, 14, 14), float32], Tensor[(256), float32], Tensor[(256), float32]) span=resnetv24_stage3_batchnorm11_fwd:0:0 */;
#   %149 = %148.0 /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_batchnorm11_fwd:0:0 */;
#   %150 = nn.relu(%149) /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_activation11:0:0 */;
#   %151 = nn.conv2d(%150, meta[relay.Constant][176] /* ty=Tensor[(1024, 256, 1, 1), float32] span=resnetv24_stage3_conv12_fwd.resnetv24_stage3_conv12_weight:0:0 */, padding=[0, 0, 0, 0], channels=1024, kernel_size=[1, 1]) /* ty=Tensor[(1, 1024, 14, 14), float32] span=resnetv24_stage3_conv12_fwd:0:0 */;
#   %152 = add(%151, %139) /* ty=Tensor[(1, 1024, 14, 14), float32] span=resnetv24_stage3__plus3:0:0 */;
#   %153 = nn.batch_norm(%152, meta[relay.Constant][177] /* ty=Tensor[(1024), float32] span=resnetv24_stage3_batchnorm12_fwd.resnetv24_stage3_batchnorm12_gamma:0:0 */, meta[relay.Constant][178] /* ty=Tensor[(1024), float32] span=resnetv24_stage3_batchnorm12_fwd.resnetv24_stage3_batchnorm12_beta:0:0 */, meta[relay.Constant][179] /* ty=Tensor[(1024), float32] span=resnetv24_stage3_batchnorm12_fwd.resnetv24_stage3_batchnorm12_running_mean:0:0 */, meta[relay.Constant][180] /* ty=Tensor[(1024), float32] span=resnetv24_stage3_batchnorm12_fwd.resnetv24_stage3_batchnorm12_running_var:0:0 */) /* ty=(Tensor[(1, 1024, 14, 14), float32], Tensor[(1024), float32], Tensor[(1024), float32]) span=resnetv24_stage3_batchnorm12_fwd:0:0 */;
#   %154 = %153.0 /* ty=Tensor[(1, 1024, 14, 14), float32] span=resnetv24_stage3_batchnorm12_fwd:0:0 */;
#   %155 = nn.relu(%154) /* ty=Tensor[(1, 1024, 14, 14), float32] span=resnetv24_stage3_activation12:0:0 */;
#   %156 = nn.conv2d(%155, meta[relay.Constant][181] /* ty=Tensor[(256, 1024, 1, 1), float32] span=resnetv24_stage3_conv13_fwd.resnetv24_stage3_conv13_weight:0:0 */, padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1]) /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_conv13_fwd:0:0 */;
#   %157 = nn.batch_norm(%156, meta[relay.Constant][182] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm13_fwd.resnetv24_stage3_batchnorm13_gamma:0:0 */, meta[relay.Constant][183] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm13_fwd.resnetv24_stage3_batchnorm13_beta:0:0 */, meta[relay.Constant][184] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm13_fwd.resnetv24_stage3_batchnorm13_running_mean:0:0 */, meta[relay.Constant][185] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm13_fwd.resnetv24_stage3_batchnorm13_running_var:0:0 */) /* ty=(Tensor[(1, 256, 14, 14), float32], Tensor[(256), float32], Tensor[(256), float32]) span=resnetv24_stage3_batchnorm13_fwd:0:0 */;
#   %158 = %157.0 /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_batchnorm13_fwd:0:0 */;
#   %159 = nn.relu(%158) /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_activation13:0:0 */;
#   %160 = nn.conv2d(%159, meta[relay.Constant][186] /* ty=Tensor[(256, 256, 3, 3), float32] span=resnetv24_stage3_conv14_fwd.resnetv24_stage3_conv14_weight:0:0 */, padding=[1, 1, 1, 1], channels=256, kernel_size=[3, 3]) /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_conv14_fwd:0:0 */;
#   %161 = nn.batch_norm(%160, meta[relay.Constant][187] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm14_fwd.resnetv24_stage3_batchnorm14_gamma:0:0 */, meta[relay.Constant][188] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm14_fwd.resnetv24_stage3_batchnorm14_beta:0:0 */, meta[relay.Constant][189] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm14_fwd.resnetv24_stage3_batchnorm14_running_mean:0:0 */, meta[relay.Constant][190] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm14_fwd.resnetv24_stage3_batchnorm14_running_var:0:0 */) /* ty=(Tensor[(1, 256, 14, 14), float32], Tensor[(256), float32], Tensor[(256), float32]) span=resnetv24_stage3_batchnorm14_fwd:0:0 */;
#   %162 = %161.0 /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_batchnorm14_fwd:0:0 */;
#   %163 = nn.relu(%162) /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_activation14:0:0 */;
#   %164 = nn.conv2d(%163, meta[relay.Constant][191] /* ty=Tensor[(1024, 256, 1, 1), float32] span=resnetv24_stage3_conv15_fwd.resnetv24_stage3_conv15_weight:0:0 */, padding=[0, 0, 0, 0], channels=1024, kernel_size=[1, 1]) /* ty=Tensor[(1, 1024, 14, 14), float32] span=resnetv24_stage3_conv15_fwd:0:0 */;
#   %165 = add(%164, %152) /* ty=Tensor[(1, 1024, 14, 14), float32] span=resnetv24_stage3__plus4:0:0 */;
# ...
#   %169 = nn.conv2d(%168, meta[relay.Constant][196] /* ty=Tensor[(256, 1024, 1, 1), float32] span=resnetv24_stage3_conv16_fwd.resnetv24_stage3_conv16_weight:0:0 */, padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1]) /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_conv16_fwd:0:0 */;
#   %170 = nn.batch_norm(%169, meta[relay.Constant][197] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm16_fwd.resnetv24_stage3_batchnorm16_gamma:0:0 */, meta[relay.Constant][198] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm16_fwd.resnetv24_stage3_batchnorm16_beta:0:0 */, meta[relay.Constant][199] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm16_fwd.resnetv24_stage3_batchnorm16_running_mean:0:0 */, meta[relay.Constant][200] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm16_fwd.resnetv24_stage3_batchnorm16_running_var:0:0 */) /* ty=(Tensor[(1, 256, 14, 14), float32], Tensor[(256), float32], Tensor[(256), float32]) span=resnetv24_stage3_batchnorm16_fwd:0:0 */;
#   %171 = %170.0 /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_batchnorm16_fwd:0:0 */;
#   %172 = nn.relu(%171) /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_activation16:0:0 */;
#   %173 = nn.conv2d(%172, meta[relay.Constant][201] /* ty=Tensor[(256, 256, 3, 3), float32] span=resnetv24_stage3_conv17_fwd.resnetv24_stage3_conv17_weight:0:0 */, padding=[1, 1, 1, 1], channels=256, kernel_size=[3, 3]) /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_conv17_fwd:0:0 */;
#   %174 = nn.batch_norm(%173, meta[relay.Constant][202] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm17_fwd.resnetv24_stage3_batchnorm17_gamma:0:0 */, meta[relay.Constant][203] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm17_fwd.resnetv24_stage3_batchnorm17_beta:0:0 */, meta[relay.Constant][204] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm17_fwd.resnetv24_stage3_batchnorm17_running_mean:0:0 */, meta[relay.Constant][205] /* ty=Tensor[(256), float32] span=resnetv24_stage3_batchnorm17_fwd.resnetv24_stage3_batchnorm17_running_var:0:0 */) /* ty=(Tensor[(1, 256, 14, 14), float32], Tensor[(256), float32], Tensor[(256), float32]) span=resnetv24_stage3_batchnorm17_fwd:0:0 */;
#   %175 = %174.0 /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_batchnorm17_fwd:0:0 */;
#   %176 = nn.relu(%175) /* ty=Tensor[(1, 256, 14, 14), float32] span=resnetv24_stage3_activation17:0:0 */;
#   %177 = nn.conv2d(%176, meta[relay.Constant][206] /* ty=Tensor[(1024, 256, 1, 1), float32] span=resnetv24_stage3_conv18_fwd.resnetv24_stage3_conv18_weight:0:0 */, padding=[0, 0, 0, 0], channels=1024, kernel_size=[1, 1]) /* ty=Tensor[(1, 1024, 14, 14), float32] span=resnetv24_stage3_conv18_fwd:0:0 */;
#   %178 = add(%177, %165) /* ty=Tensor[(1, 1024, 14, 14), float32] span=resnetv24_stage3__plus5:0:0 */;
#   %179 = nn.batch_norm(%178, meta[relay.Constant][207] /* ty=Tensor[(1024), float32] span=resnetv24_stage4_batchnorm0_fwd.resnetv24_stage4_batchnorm0_gamma:0:0 */, meta[relay.Constant][208] /* ty=Tensor[(1024), float32] span=resnetv24_stage4_batchnorm0_fwd.resnetv24_stage4_batchnorm0_beta:0:0 */, meta[relay.Constant][209] /* ty=Tensor[(1024), float32] span=resnetv24_stage4_batchnorm0_fwd.resnetv24_stage4_batchnorm0_running_mean:0:0 */, meta[relay.Constant][210] /* ty=Tensor[(1024), float32] span=resnetv24_stage4_batchnorm0_fwd.resnetv24_stage4_batchnorm0_running_var:0:0 */) /* ty=(Tensor[(1, 1024, 14, 14), float32], Tensor[(1024), float32], Tensor[(1024), float32]) span=resnetv24_stage4_batchnorm0_fwd:0:0 */;
#   %180 = %179.0 /* ty=Tensor[(1, 1024, 14, 14), float32] span=resnetv24_stage4_batchnorm0_fwd:0:0 */;
#   %181 = nn.relu(%180) /* ty=Tensor[(1, 1024, 14, 14), float32] span=resnetv24_stage4_activation0:0:0 */;
#   %182 = nn.conv2d(%181, meta[relay.Constant][211] /* ty=Tensor[(512, 1024, 1, 1), float32] span=resnetv24_stage4_conv0_fwd.resnetv24_stage4_conv0_weight:0:0 */, padding=[0, 0, 0, 0], channels=512, kernel_size=[1, 1]) /* ty=Tensor[(1, 512, 14, 14), float32] span=resnetv24_stage4_conv0_fwd:0:0 */;
#   %183 = nn.batch_norm(%182, meta[relay.Constant][212] /* ty=Tensor[(512), float32] span=resnetv24_stage4_batchnorm1_fwd.resnetv24_stage4_batchnorm1_gamma:0:0 */, meta[relay.Constant][213] /* ty=Tensor[(512), float32] span=resnetv24_stage4_batchnorm1_fwd.resnetv24_stage4_batchnorm1_beta:0:0 */, meta[relay.Constant][214] /* ty=Tensor[(512), float32] span=resnetv24_stage4_batchnorm1_fwd.resnetv24_stage4_batchnorm1_running_mean:0:0 */, meta[relay.Constant][215] /* ty=Tensor[(512), float32] span=resnetv24_stage4_batchnorm1_fwd.resnetv24_stage4_batchnorm1_running_var:0:0 */) /* ty=(Tensor[(1, 512, 14, 14), float32], Tensor[(512), float32], Tensor[(512), float32]) span=resnetv24_stage4_batchnorm1_fwd:0:0 */;
#   %184 = %183.0 /* ty=Tensor[(1, 512, 14, 14), float32] span=resnetv24_stage4_batchnorm1_fwd:0:0 */;
#   %185 = nn.relu(%184) /* ty=Tensor[(1, 512, 14, 14), float32] span=resnetv24_stage4_activation1:0:0 */;
#   %186 = nn.conv2d(%185, meta[relay.Constant][216] /* ty=Tensor[(512, 512, 3, 3), float32] span=resnetv24_stage4_conv1_fwd.resnetv24_stage4_conv1_weight:0:0 */, strides=[2, 2], padding=[1, 1, 1, 1], channels=512, kernel_size=[3, 3]) /* ty=Tensor[(1, 512, 7, 7), float32] span=resnetv24_stage4_conv1_fwd:0:0 */;
#   %187 = nn.batch_norm(%186, meta[relay.Constant][217] /* ty=Tensor[(512), float32] span=resnetv24_stage4_batchnorm2_fwd.resnetv24_stage4_batchnorm2_gamma:0:0 */, meta[relay.Constant][218] /* ty=Tensor[(512), float32] span=resnetv24_stage4_batchnorm2_fwd.resnetv24_stage4_batchnorm2_beta:0:0 */, meta[relay.Constant][219] /* ty=Tensor[(512), float32] span=resnetv24_stage4_batchnorm2_fwd.resnetv24_stage4_batchnorm2_running_mean:0:0 */, meta[relay.Constant][220] /* ty=Tensor[(512), float32] span=resnetv24_stage4_batchnorm2_fwd.resnetv24_stage4_batchnorm2_running_var:0:0 */) /* ty=(Tensor[(1, 512, 7, 7), float32], Tensor[(512), float32], Tensor[(512), float32]) span=resnetv24_stage4_batchnorm2_fwd:0:0 */;
#   %188 = %187.0 /* ty=Tensor[(1, 512, 7, 7), float32] span=resnetv24_stage4_batchnorm2_fwd:0:0 */;
#   %189 = nn.relu(%188) /* ty=Tensor[(1, 512, 7, 7), float32] span=resnetv24_stage4_activation2:0:0 */;
#   %190 = nn.conv2d(%189, meta[relay.Constant][221] /* ty=Tensor[(2048, 512, 1, 1), float32] span=resnetv24_stage4_conv2_fwd.resnetv24_stage4_conv2_weight:0:0 */, padding=[0, 0, 0, 0], channels=2048, kernel_size=[1, 1]) /* ty=Tensor[(1, 2048, 7, 7), float32] span=resnetv24_stage4_conv2_fwd:0:0 */;
#   %191 = nn.conv2d(%181, meta[relay.Constant][222] /* ty=Tensor[(2048, 1024, 1, 1), float32] span=resnetv24_stage4_conv3_fwd.resnetv24_stage4_conv3_weight:0:0 */, strides=[2, 2], padding=[0, 0, 0, 0], channels=2048, kernel_size=[1, 1]) /* ty=Tensor[(1, 2048, 7, 7), float32] span=resnetv24_stage4_conv3_fwd:0:0 */;
#   %192 = add(%190, %191) /* ty=Tensor[(1, 2048, 7, 7), float32] span=resnetv24_stage4__plus0:0:0 */;
#   %193 = nn.batch_norm(%192, meta[relay.Constant][223] /* ty=Tensor[(2048), float32] span=resnetv24_stage4_batchnorm3_fwd.resnetv24_stage4_batchnorm3_gamma:0:0 */, meta[relay.Constant][224] /* ty=Tensor[(2048), float32] span=resnetv24_stage4_batchnorm3_fwd.resnetv24_stage4_batchnorm3_beta:0:0 */, meta[relay.Constant][225] /* ty=Tensor[(2048), float32] span=resnetv24_stage4_batchnorm3_fwd.resnetv24_stage4_batchnorm3_running_mean:0:0 */, meta[relay.Constant][226] /* ty=Tensor[(2048), float32] span=resnetv24_stage4_batchnorm3_fwd.resnetv24_stage4_batchnorm3_running_var:0:0 */) /* ty=(Tensor[(1, 2048, 7, 7), float32], Tensor[(2048), float32], Tensor[(2048), float32]) span=resnetv24_stage4_batchnorm3_fwd:0:0 */;
#   %194 = %193.0 /* ty=Tensor[(1, 2048, 7, 7), float32] span=resnetv24_stage4_batchnorm3_fwd:0:0 */;
#   %195 = nn.relu(%194) /* ty=Tensor[(1, 2048, 7, 7), float32] span=resnetv24_stage4_activation3:0:0 */;
#   %196 = nn.conv2d(%195, meta[relay.Constant][227] /* ty=Tensor[(512, 2048, 1, 1), float32] span=resnetv24_stage4_conv4_fwd.resnetv24_stage4_conv4_weight:0:0 */, padding=[0, 0, 0, 0], channels=512, kernel_size=[1, 1]) /* ty=Tensor[(1, 512, 7, 7), float32] span=resnetv24_stage4_conv4_fwd:0:0 */;
#   %197 = nn.batch_norm(%196, meta[relay.Constant][228] /* ty=Tensor[(512), float32] span=resnetv24_stage4_batchnorm4_fwd.resnetv24_stage4_batchnorm4_gamma:0:0 */, meta[relay.Constant][229] /* ty=Tensor[(512), float32] span=resnetv24_stage4_batchnorm4_fwd.resnetv24_stage4_batchnorm4_beta:0:0 */, meta[relay.Constant][230] /* ty=Tensor[(512), float32] span=resnetv24_stage4_batchnorm4_fwd.resnetv24_stage4_batchnorm4_running_mean:0:0 */, meta[relay.Constant][231] /* ty=Tensor[(512), float32] span=resnetv24_stage4_batchnorm4_fwd.resnetv24_stage4_batchnorm4_running_var:0:0 */) /* ty=(Tensor[(1, 512, 7, 7), float32], Tensor[(512), float32], Tensor[(512), float32]) span=resnetv24_stage4_batchnorm4_fwd:0:0 */;
#   %198 = %197.0 /* ty=Tensor[(1, 512, 7, 7), float32] span=resnetv24_stage4_batchnorm4_fwd:0:0 */;
#   %199 = nn.relu(%198) /* ty=Tensor[(1, 512, 7, 7), float32] span=resnetv24_stage4_activation4:0:0 */;
#   %200 = nn.conv2d(%199, meta[relay.Constant][232] /* ty=Tensor[(512, 512, 3, 3), float32] span=resnetv24_stage4_conv5_fwd.resnetv24_stage4_conv5_weight:0:0 */, padding=[1, 1, 1, 1], channels=512, kernel_size=[3, 3]) /* ty=Tensor[(1, 512, 7, 7), float32] span=resnetv24_stage4_conv5_fwd:0:0 */;
#   %201 = nn.batch_norm(%200, meta[relay.Constant][233] /* ty=Tensor[(512), float32] span=resnetv24_stage4_batchnorm5_fwd.resnetv24_stage4_batchnorm5_gamma:0:0 */, meta[relay.Constant][234] /* ty=Tensor[(512), float32] span=resnetv24_stage4_batchnorm5_fwd.resnetv24_stage4_batchnorm5_beta:0:0 */, meta[relay.Constant][235] /* ty=Tensor[(512), float32] span=resnetv24_stage4_batchnorm5_fwd.resnetv24_stage4_batchnorm5_running_mean:0:0 */, meta[relay.Constant][236] /* ty=Tensor[(512), float32] span=resnetv24_stage4_batchnorm5_fwd.resnetv24_stage4_batchnorm5_running_var:0:0 */) /* ty=(Tensor[(1, 512, 7, 7), float32], Tensor[(512), float32], Tensor[(512), float32]) span=resnetv24_stage4_batchnorm5_fwd:0:0 */;
#   %202 = %201.0 /* ty=Tensor[(1, 512, 7, 7), float32] span=resnetv24_stage4_batchnorm5_fwd:0:0 */;
#   %203 = nn.relu(%202) /* ty=Tensor[(1, 512, 7, 7), float32] span=resnetv24_stage4_activation5:0:0 */;
#   %204 = nn.conv2d(%203, meta[relay.Constant][237] /* ty=Tensor[(2048, 512, 1, 1), float32] span=resnetv24_stage4_conv6_fwd.resnetv24_stage4_conv6_weight:0:0 */, padding=[0, 0, 0, 0], channels=2048, kernel_size=[1, 1]) /* ty=Tensor[(1, 2048, 7, 7), float32] span=resnetv24_stage4_conv6_fwd:0:0 */;
#   %205 = add(%204, %192) /* ty=Tensor[(1, 2048, 7, 7), float32] span=resnetv24_stage4__plus1:0:0 */;
#   %206 = nn.batch_norm(%205, meta[relay.Constant][238] /* ty=Tensor[(2048), float32] span=resnetv24_stage4_batchnorm6_fwd.resnetv24_stage4_batchnorm6_gamma:0:0 */, meta[relay.Constant][239] /* ty=Tensor[(2048), float32] span=resnetv24_stage4_batchnorm6_fwd.resnetv24_stage4_batchnorm6_beta:0:0 */, meta[relay.Constant][240] /* ty=Tensor[(2048), float32] span=resnetv24_stage4_batchnorm6_fwd.resnetv24_stage4_batchnorm6_running_mean:0:0 */, meta[relay.Constant][241] /* ty=Tensor[(2048), float32] span=resnetv24_stage4_batchnorm6_fwd.resnetv24_stage4_batchnorm6_running_var:0:0 */) /* ty=(Tensor[(1, 2048, 7, 7), float32], Tensor[(2048), float32], Tensor[(2048), float32]) span=resnetv24_stage4_batchnorm6_fwd:0:0 */;
#   %207 = %206.0 /* ty=Tensor[(1, 2048, 7, 7), float32] span=resnetv24_stage4_batchnorm6_fwd:0:0 */;
#   %208 = nn.relu(%207) /* ty=Tensor[(1, 2048, 7, 7), float32] span=resnetv24_stage4_activation6:0:0 */;
#   %209 = nn.conv2d(%208, meta[relay.Constant][242] /* ty=Tensor[(512, 2048, 1, 1), float32] span=resnetv24_stage4_conv7_fwd.resnetv24_stage4_conv7_weight:0:0 */, padding=[0, 0, 0, 0], channels=512, kernel_size=[1, 1]) /* ty=Tensor[(1, 512, 7, 7), float32] span=resnetv24_stage4_conv7_fwd:0:0 */;
#   %210 = nn.batch_norm(%209, meta[relay.Constant][243] /* ty=Tensor[(512), float32] span=resnetv24_stage4_batchnorm7_fwd.resnetv24_stage4_batchnorm7_gamma:0:0 */, meta[relay.Constant][244] /* ty=Tensor[(512), float32] span=resnetv24_stage4_batchnorm7_fwd.resnetv24_stage4_batchnorm7_beta:0:0 */, meta[relay.Constant][245] /* ty=Tensor[(512), float32] span=resnetv24_stage4_batchnorm7_fwd.resnetv24_stage4_batchnorm7_running_mean:0:0 */, meta[relay.Constant][246] /* ty=Tensor[(512), float32] span=resnetv24_stage4_batchnorm7_fwd.resnetv24_stage4_batchnorm7_running_var:0:0 */) /* ty=(Tensor[(1, 512, 7, 7), float32], Tensor[(512), float32], Tensor[(512), float32]) span=resnetv24_stage4_batchnorm7_fwd:0:0 */;
#   %211 = %210.0 /* ty=Tensor[(1, 512, 7, 7), float32] span=resnetv24_stage4_batchnorm7_fwd:0:0 */;
#   %212 = nn.relu(%211) /* ty=Tensor[(1, 512, 7, 7), float32] span=resnetv24_stage4_activation7:0:0 */;
#   %213 = nn.conv2d(%212, meta[relay.Constant][247] /* ty=Tensor[(512, 512, 3, 3), float32] span=resnetv24_stage4_conv8_fwd.resnetv24_stage4_conv8_weight:0:0 */, padding=[1, 1, 1, 1], channels=512, kernel_size=[3, 3]) /* ty=Tensor[(1, 512, 7, 7), float32] span=resnetv24_stage4_conv8_fwd:0:0 */;
#   %214 = nn.batch_norm(%213, meta[relay.Constant][248] /* ty=Tensor[(512), float32] span=resnetv24_stage4_batchnorm8_fwd.resnetv24_stage4_batchnorm8_gamma:0:0 */, meta[relay.Constant][249] /* ty=Tensor[(512), float32] span=resnetv24_stage4_batchnorm8_fwd.resnetv24_stage4_batchnorm8_beta:0:0 */, meta[relay.Constant][250] /* ty=Tensor[(512), float32] span=resnetv24_stage4_batchnorm8_fwd.resnetv24_stage4_batchnorm8_running_mean:0:0 */, meta[relay.Constant][251] /* ty=Tensor[(512), float32] span=resnetv24_stage4_batchnorm8_fwd.resnetv24_stage4_batchnorm8_running_var:0:0 */) /* ty=(Tensor[(1, 512, 7, 7), float32], Tensor[(512), float32], Tensor[(512), float32]) span=resnetv24_stage4_batchnorm8_fwd:0:0 */;
#   %215 = %214.0 /* ty=Tensor[(1, 512, 7, 7), float32] span=resnetv24_stage4_batchnorm8_fwd:0:0 */;
#   %216 = nn.relu(%215) /* ty=Tensor[(1, 512, 7, 7), float32] span=resnetv24_stage4_activation8:0:0 */;
#   %217 = nn.conv2d(%216, meta[relay.Constant][252] /* ty=Tensor[(2048, 512, 1, 1), float32] span=resnetv24_stage4_conv9_fwd.resnetv24_stage4_conv9_weight:0:0 */, padding=[0, 0, 0, 0], channels=2048, kernel_size=[1, 1]) /* ty=Tensor[(1, 2048, 7, 7), float32] span=resnetv24_stage4_conv9_fwd:0:0 */;
#   %218 = add(%217, %205) /* ty=Tensor[(1, 2048, 7, 7), float32] span=resnetv24_stage4__plus2:0:0 */;
#   %219 = nn.batch_norm(%218, meta[relay.Constant][253] /* ty=Tensor[(2048), float32] span=resnetv24_batchnorm2_fwd.resnetv24_batchnorm2_gamma:0:0 */, meta[relay.Constant][254] /* ty=Tensor[(2048), float32] span=resnetv24_batchnorm2_fwd.resnetv24_batchnorm2_beta:0:0 */, meta[relay.Constant][255] /* ty=Tensor[(2048), float32] span=resnetv24_batchnorm2_fwd.resnetv24_batchnorm2_running_mean:0:0 */, meta[relay.Constant][256] /* ty=Tensor[(2048), float32] span=resnetv24_batchnorm2_fwd.resnetv24_batchnorm2_running_var:0:0 */) /* ty=(Tensor[(1, 2048, 7, 7), float32], Tensor[(2048), float32], Tensor[(2048), float32]) span=resnetv24_batchnorm2_fwd:0:0 */;
#   %220 = %219.0 /* ty=Tensor[(1, 2048, 7, 7), float32] span=resnetv24_batchnorm2_fwd:0:0 */;
#   %221 = nn.relu(%220) /* ty=Tensor[(1, 2048, 7, 7), float32] span=resnetv24_relu1_fwd:0:0 */;
#   %222 = nn.global_avg_pool2d(%221) /* ty=Tensor[(1, 2048, 1, 1), float32] span=resnetv24_pool1_fwd:0:0 */;
#   %223 = reshape(%222, newshape=[0, -1]) /* ty=Tensor[(1, 2048), float32] span=resnetv24_flatten0_reshape0:0:0 */;
#   %224 = nn.dense(%223, meta[relay.Constant][257] /* ty=Tensor[(1000, 2048), float32] span=resnetv24_dense0_fwd.resnetv24_dense0_weight:0:0 */, units=1000) /* ty=Tensor[(1, 1000), float32] span=resnetv24_dense0_fwd:0:0 */;
#   add(%224, meta[relay.Constant][258] /* ty=Tensor[(1000), float32] span=resnetv24_dense0_fwd.resnetv24_dense0_bias:0:0 */) /* ty=Tensor[(1, 1000), float32] span=resnetv24_dense0_fwd:0:0 */
# }

# %% [markdown]
# ## Step 2: Compile
#
# Now that our model is in Relay, our next step is to compile it to a desired
# hardware to run on. We refer to this hardware as a target. This compilation process
# translates the model from Relay into a lower-level language that the
# target machine can understand.
#
# In order to compile a model a tvm.target string is required.
# To learn more about tvm.targets and their options look at the [documentation](https://tvm.apache.org/docs/api/python/target.html).
# Some examples include:
#
#    1. cuda (Nvidia GPU)
#    2. llvm (CPU)
#    3. llvm -mcpu=cascadelake (Intel CPU)
#
# ```python
# package = tvmc.compile(model, target="llvm") #Step 2: Compile
# ```
# The compilation step returns a package.

# %%
package = tvmc.compile(model, target='cuda')
# Out:
# One or more operators have not been tuned. Please tune your model for better performance. Use DEBUG logging level to see more details.

# %% [markdown]
# ## Step 3: Run
#
# The compiled package can now be run on the hardware target. The device
# input options are: CPU, Cuda, CL, Metal, and Vulkan.
#
# ```python
# result = tvmc.run(package, device="cpu") #Step 3: Run
# ```
# And you can print the results:
# ``print(result)``

# %%
result = tvmc.run(package, device='cuda')
# Out:
# 2024-03-29 04:37:59.413 INFO load_module /tmp/tmpsfxopq56/mod.so

# %%
print(f'result: {result}')

# %% [markdown]
# ## Step 1.5: Tune [Optional & Recommended]
#
# Run speed can further be improved by tuning. This optional step uses
# machine learning to look at each operation within a model (a function) and
# tries to find a faster way to run it. We do this through a cost model, and
# benchmarking possible schedules.
#
# The target is the same as compile.
#
# ```python
# tvmc.tune(model, target="llvm") #Step 1.5: Optional Tune
# ```
# The terminal output should look like:
#
# ```python
# [Task  1/13]  Current/Best:   82.00/ 106.29 GFLOPS | Progress: (48/769) | 18.56 s
# [Task  1/13]  Current/Best:   54.47/ 113.50 GFLOPS | Progress: (240/769) | 85.36 s
# .....
# ```
# There may be UserWarnings that can be ignored.
# This should make the end result faster, but it can take hours to tune.
#
# See the section 'Saving the Tuning Results' below. Be sure to pass the tuning
# results into compile if you want the results to apply.
#
# ```python
# #tvmc.compile(model, target="llvm", tuning_records = "records.log") #Step 2: Compile
# ```

# %%
! pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /home/nyck33/miniconda3/envs/tvm-cu116-py310/lib/python3.10/site-packages (2.0.3)
# Requirement already satisfied: numpy in /home/nyck33/miniconda3/envs/tvm-cu116-py310/lib/python3.10/site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in /home/nyck33/miniconda3/envs/tvm-cu116-py310/lib/python3.10/site-packages (from xgboost) (1.12.0)

# %%
#tvmc.tune(model, target='llvm')

log_file = 'cuda_tuning.json'

#tvmc.tune(model, target='cuda', enable_autoscheduler=True, tuning_records=log_file)

# tune again
tvmc.tune(model, target='cuda', enable_autoscheduler=True, prior_records=log_file, tuning_records=log_file)
# Out:
# Get devices for measurement successfully!
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 64 measurement records from cuda_tuning.json for ["22c6bcc64d9aa81c000bdfbeb7613711", [1, 128, 56, 56], [128, 128, 3, 3], [1, 128, 1, 1], [1, 128, 28, 28]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["0a667992e22b17837e8153301b385cc0", [1, 64, 56, 56], [256, 64, 1, 1], [1, 256, 56, 56], [1, 256, 56, 56]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["9a384172b7d3de1a1c2958791a5e5bca", [1, 64, 56, 56], [256, 64, 1, 1], [1, 256, 56, 56]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["09b917b9f7ace9bf34bb183a3c1f0e0c", [1, 64, 56, 56], [64, 64, 1, 1], [1, 64, 1, 1], [1, 64, 56, 56]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["08f7449d79e570b7274174709e5e5e01", [1, 2048], [1000, 2048], [1, 1000], [1, 1000]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["22c6bcc64d9aa81c000bdfbeb7613711", [1, 512, 14, 14], [512, 512, 3, 3], [1, 512, 1, 1], [1, 512, 7, 7]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["0a667992e22b17837e8153301b385cc0", [1, 512, 7, 7], [2048, 512, 1, 1], [1, 2048, 7, 7], [1, 2048, 7, 7]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["da640b59f7f83066caed1c4a23175a18", [1, 2048, 7, 7], [1, 2048, 1, 1]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["09b917b9f7ace9bf34bb183a3c1f0e0c", [1, 512, 28, 28], [256, 512, 1, 1], [1, 256, 1, 1], [1, 256, 28, 28]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["3644602720e6e75fc262c938b0100cab", [1, 64, 56, 56], [256, 64, 1, 1], [1, 256, 56, 56], [1, 256, 1, 1], [1, 256, 56, 56]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["9b2cf35c7122118f565cacc4ddb8c43d", [1, 1024, 14, 14], [2048, 1024, 1, 1], [1, 2048, 7, 7]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["09b917b9f7ace9bf34bb183a3c1f0e0c", [1, 256, 56, 56], [128, 256, 1, 1], [1, 128, 1, 1], [1, 128, 56, 56]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["9b2cf35c7122118f565cacc4ddb8c43d", [1, 256, 56, 56], [512, 256, 1, 1], [1, 512, 28, 28]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["09b917b9f7ace9bf34bb183a3c1f0e0c", [1, 2048, 7, 7], [512, 2048, 1, 1], [1, 512, 1, 1], [1, 512, 7, 7]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["3644602720e6e75fc262c938b0100cab", [1, 128, 28, 28], [512, 128, 1, 1], [1, 512, 28, 28], [1, 512, 1, 1], [1, 512, 28, 28]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["0a667992e22b17837e8153301b385cc0", [1, 256, 14, 14], [1024, 256, 1, 1], [1, 1024, 14, 14], [1, 1024, 14, 14]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["22c6bcc64d9aa81c000bdfbeb7613711", [1, 3, 224, 224], [64, 3, 7, 7], [1, 64, 1, 1], [1, 64, 112, 112]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["c75fea8a729fa8512d4c275837a40cc4", [1, 128, 28, 28], [128, 128, 3, 3], [1, 128, 1, 1], [1, 128, 28, 28]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["09b917b9f7ace9bf34bb183a3c1f0e0c", [1, 1024, 14, 14], [256, 1024, 1, 1], [1, 256, 1, 1], [1, 256, 14, 14]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["498c1c3b7138181b2b4556b2bbdc332d", [1, 64, 112, 112], [1, 64, 1, 1], [1, 64, 1, 1], [1, 64, 56, 56]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["09b917b9f7ace9bf34bb183a3c1f0e0c", [1, 256, 56, 56], [64, 256, 1, 1], [1, 64, 1, 1], [1, 64, 56, 56]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["c75fea8a729fa8512d4c275837a40cc4", [1, 512, 7, 7], [512, 512, 3, 3], [1, 512, 1, 1], [1, 512, 7, 7]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["f9b90fd6168022dade72fec502df8499", [1, 512, 7, 7], [2048, 512, 1, 1], [1, 2048, 7, 7], [1, 2048, 1, 1], [1, 2048, 1, 1], [1, 2048, 7, 7]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["c75fea8a729fa8512d4c275837a40cc4", [1, 256, 14, 14], [256, 256, 3, 3], [1, 256, 1, 1], [1, 256, 14, 14]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["0a667992e22b17837e8153301b385cc0", [1, 128, 28, 28], [512, 128, 1, 1], [1, 512, 28, 28], [1, 512, 28, 28]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["9b2cf35c7122118f565cacc4ddb8c43d", [1, 512, 28, 28], [1024, 512, 1, 1], [1, 1024, 14, 14]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["09b917b9f7ace9bf34bb183a3c1f0e0c", [1, 512, 28, 28], [128, 512, 1, 1], [1, 128, 1, 1], [1, 128, 28, 28]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["3644602720e6e75fc262c938b0100cab", [1, 256, 14, 14], [1024, 256, 1, 1], [1, 1024, 14, 14], [1, 1024, 1, 1], [1, 1024, 14, 14]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["c75fea8a729fa8512d4c275837a40cc4", [1, 64, 56, 56], [64, 64, 3, 3], [1, 64, 1, 1], [1, 64, 56, 56]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["22c6bcc64d9aa81c000bdfbeb7613711", [1, 256, 28, 28], [256, 256, 3, 3], [1, 256, 1, 1], [1, 256, 14, 14]]
# ----------------------------------------------------------------------
# ------------------------------  [ Call init-search callbacks ]
# ----------------------------------------------------------------------
# SearchPolicy: Loaded 0 measurement records from cuda_tuning.json for ["09b917b9f7ace9bf34bb183a3c1f0e0c", [1, 1024, 14, 14], [512, 1024, 1, 1], [1, 512, 1, 1], [1, 512, 14, 14]]
# |  ID  |                       Task Description                        | Latency (ms) | Speed (GFLOPS) | Trials |
# -----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------
# ------------------------------  [ Task Scheduler ]
# ----------------------------------------------------------------------
# |    0 |                          vm_mod_fused_nn_conv2d_add_nn_relu_5 |        0.251 |         922.61 |     64 |
# |    1 |                                    vm_mod_fused_nn_conv2d_add |            - |              - |      0 |
# |    2 |                                        vm_mod_fused_nn_conv2d |            - |              - |      0 |
# |    3 |                          vm_mod_fused_nn_conv2d_add_nn_relu_1 |            - |              - |      0 |
# |    4 |                                     vm_mod_fused_nn_dense_add |            - |              - |      0 |
# |    5 |                         vm_mod_fused_nn_conv2d_add_nn_relu_13 |            - |              - |      0 |
# |    6 |                                  vm_mod_fused_nn_conv2d_add_3 |            - |              - |      0 |
# |    7 |                             vm_mod_fused_nn_global_avg_pool2d |            - |              - |      0 |
# |    8 |                          vm_mod_fused_nn_conv2d_add_nn_relu_8 |            - |              - |      0 |
# |    9 |                        vm_mod_fused_nn_conv2d_add_add_nn_relu |            - |              - |      0 |
# |   10 |                                      vm_mod_fused_nn_conv2d_3 |            - |              - |      0 |
# |   11 |                          vm_mod_fused_nn_conv2d_add_nn_relu_4 |            - |              - |      0 |
# |   12 |                                      vm_mod_fused_nn_conv2d_1 |            - |              - |      0 |
# |   13 |                         vm_mod_fused_nn_conv2d_add_nn_relu_14 |            - |              - |      0 |
# |   14 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_1 |            - |              - |      0 |
# |   15 |                                  vm_mod_fused_nn_conv2d_add_2 |            - |              - |      0 |
# |   16 |                            vm_mod_fused_nn_conv2d_add_nn_relu |            - |              - |      0 |
# |   17 |                          vm_mod_fused_nn_conv2d_add_nn_relu_7 |            - |              - |      0 |
# |   18 |                         vm_mod_fused_nn_conv2d_add_nn_relu_10 |            - |              - |      0 |
# |   19 |               vm_mod_fused_nn_max_pool2d_multiply_add_nn_relu |            - |              - |      0 |
# |   20 |                          vm_mod_fused_nn_conv2d_add_nn_relu_3 |            - |              - |      0 |
# |   21 |                         vm_mod_fused_nn_conv2d_add_nn_relu_15 |            - |              - |      0 |
# |   22 |               vm_mod_fused_nn_conv2d_add_multiply_add_nn_relu |            - |              - |      0 |
# |   23 |                         vm_mod_fused_nn_conv2d_add_nn_relu_11 |            - |              - |      0 |
# |   24 |                                  vm_mod_fused_nn_conv2d_add_1 |            - |              - |      0 |
# |   25 |                                      vm_mod_fused_nn_conv2d_2 |            - |              - |      0 |
# |   26 |                          vm_mod_fused_nn_conv2d_add_nn_relu_6 |            - |              - |      0 |
# |   27 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_2 |            - |              - |      0 |
# |   28 |                          vm_mod_fused_nn_conv2d_add_nn_relu_2 |            - |              - |      0 |
# |   29 |                          vm_mod_fused_nn_conv2d_add_nn_relu_9 |            - |              - |      0 |
# |   30 |                         vm_mod_fused_nn_conv2d_add_nn_relu_12 |            - |              - |      0 |
# -----------------------------------------------------------------------------------------------------------------
# Estimated total latency: - ms	Trials: 0	Used time : 1 s	Next ID: 1
# ----------------------------------------------------------------------
# ------------------------------  [ Search ]
# ----------------------------------------------------------------------
# Generate Sketches		#s: 1
# Sample Initial Population	#s: 169	fail_ct: 1879	Time elapsed: 3.75
# GA Iter: 0	Max score: 0.9950	Min score: 0.2611	#Pop: 128	#M+: 0	#M-: 0
# GA Iter: 4	Max score: 0.9999	Min score: 0.9797	#Pop: 128	#M+: 1393	#M-: 0
# EvolutionarySearch		#s: 128	Time elapsed: 50.33
# ----------------------------------------------------------------------
# ------------------------------  [ Measure ]
# ----------------------------------------------------------------------
# Get 64 programs to measure:
# ............T***********
# ............************
# ............************
# ............************
# ............************
# ....****
# Time elapsed for measurement: 224.69 s
# ----------------------------------------------------------------------
# ------------------------------  [ Train cost model ]
# ----------------------------------------------------------------------
# Time elapsed for training: 0.46 s
# ----------------------------------------------------------------------
# |  ID  |                       Task Description                        | Latency (ms) | Speed (GFLOPS) | Trials |
# -----------------------------------------------------------------------------------------------------------------
# ------------------------------  [ Task Scheduler ]
# ----------------------------------------------------------------------
# |    0 |                          vm_mod_fused_nn_conv2d_add_nn_relu_5 |        0.251 |         922.61 |     64 |
# |    1 |                                    vm_mod_fused_nn_conv2d_add |        0.138 |         751.82 |     64 |
# |    2 |                                        vm_mod_fused_nn_conv2d |            - |              - |      0 |
# |    3 |                          vm_mod_fused_nn_conv2d_add_nn_relu_1 |            - |              - |      0 |
# |    4 |                                     vm_mod_fused_nn_dense_add |            - |              - |      0 |
# |    5 |                         vm_mod_fused_nn_conv2d_add_nn_relu_13 |            - |              - |      0 |
# |    6 |                                  vm_mod_fused_nn_conv2d_add_3 |            - |              - |      0 |
# |    7 |                             vm_mod_fused_nn_global_avg_pool2d |            - |              - |      0 |
# |    8 |                          vm_mod_fused_nn_conv2d_add_nn_relu_8 |            - |              - |      0 |
# |    9 |                        vm_mod_fused_nn_conv2d_add_add_nn_relu |            - |              - |      0 |
# |   10 |                                      vm_mod_fused_nn_conv2d_3 |            - |              - |      0 |
# |   11 |                          vm_mod_fused_nn_conv2d_add_nn_relu_4 |            - |              - |      0 |
# |   12 |                                      vm_mod_fused_nn_conv2d_1 |            - |              - |      0 |
# |   13 |                         vm_mod_fused_nn_conv2d_add_nn_relu_14 |            - |              - |      0 |
# |   14 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_1 |            - |              - |      0 |
# |   15 |                                  vm_mod_fused_nn_conv2d_add_2 |            - |              - |      0 |
# |   16 |                            vm_mod_fused_nn_conv2d_add_nn_relu |            - |              - |      0 |
# |   17 |                          vm_mod_fused_nn_conv2d_add_nn_relu_7 |            - |              - |      0 |
# |   18 |                         vm_mod_fused_nn_conv2d_add_nn_relu_10 |            - |              - |      0 |
# |   19 |               vm_mod_fused_nn_max_pool2d_multiply_add_nn_relu |            - |              - |      0 |
# |   20 |                          vm_mod_fused_nn_conv2d_add_nn_relu_3 |            - |              - |      0 |
# |   21 |                         vm_mod_fused_nn_conv2d_add_nn_relu_15 |            - |              - |      0 |
# |   22 |               vm_mod_fused_nn_conv2d_add_multiply_add_nn_relu |            - |              - |      0 |
# |   23 |                         vm_mod_fused_nn_conv2d_add_nn_relu_11 |            - |              - |      0 |
# |   24 |                                  vm_mod_fused_nn_conv2d_add_1 |            - |              - |      0 |
# |   25 |                                      vm_mod_fused_nn_conv2d_2 |            - |              - |      0 |
# |   26 |                          vm_mod_fused_nn_conv2d_add_nn_relu_6 |            - |              - |      0 |
# |   27 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_2 |            - |              - |      0 |
# |   28 |                          vm_mod_fused_nn_conv2d_add_nn_relu_2 |            - |              - |      0 |
# |   29 |                          vm_mod_fused_nn_conv2d_add_nn_relu_9 |            - |              - |      0 |
# |   30 |                         vm_mod_fused_nn_conv2d_add_nn_relu_12 |            - |              - |      0 |
# -----------------------------------------------------------------------------------------------------------------
# Estimated total latency: - ms	Trials: 64	Used time : 280 s	Next ID: 2
# ----------------------------------------------------------------------
# ------------------------------  [ Search ]
# ----------------------------------------------------------------------
# Generate Sketches		#s: 1
# Sample Initial Population	#s: 153	fail_ct: 1895	Time elapsed: 4.66
# GA Iter: 0	Max score: 0.9960	Min score: 0.1078	#Pop: 128	#M+: 0	#M-: 0
# GA Iter: 4	Max score: 0.9998	Min score: 0.9811	#Pop: 128	#M+: 1396	#M-: 0
# EvolutionarySearch		#s: 128	Time elapsed: 58.03
# ----------------------------------------------------------------------
# ------------------------------  [ Measure ]
# ----------------------------------------------------------------------
# Get 64 programs to measure:
# ............************
# ............T***********
# ............************
# ............************
# ............************
# ....****
# Time elapsed for measurement: 201.86 s
# ----------------------------------------------------------------------
# ------------------------------  [ Train cost model ]
# ----------------------------------------------------------------------
# Time elapsed for training: 0.41 s
# |  ID  |                       Task Description                        | Latency (ms) | Speed (GFLOPS) | Trials |
# -----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------
# ------------------------------  [ Task Scheduler ]
# ----------------------------------------------------------------------
# |    0 |                          vm_mod_fused_nn_conv2d_add_nn_relu_5 |        0.251 |         922.61 |     64 |
# |    1 |                                    vm_mod_fused_nn_conv2d_add |        0.138 |         751.82 |     64 |
# |    2 |                                        vm_mod_fused_nn_conv2d |        0.086 |        1189.30 |     64 |
# |    3 |                          vm_mod_fused_nn_conv2d_add_nn_relu_1 |            - |              - |      0 |
# |    4 |                                     vm_mod_fused_nn_dense_add |            - |              - |      0 |
# |    5 |                         vm_mod_fused_nn_conv2d_add_nn_relu_13 |            - |              - |      0 |
# |    6 |                                  vm_mod_fused_nn_conv2d_add_3 |            - |              - |      0 |
# |    7 |                             vm_mod_fused_nn_global_avg_pool2d |            - |              - |      0 |
# |    8 |                          vm_mod_fused_nn_conv2d_add_nn_relu_8 |            - |              - |      0 |
# |    9 |                        vm_mod_fused_nn_conv2d_add_add_nn_relu |            - |              - |      0 |
# |   10 |                                      vm_mod_fused_nn_conv2d_3 |            - |              - |      0 |
# |   11 |                          vm_mod_fused_nn_conv2d_add_nn_relu_4 |            - |              - |      0 |
# |   12 |                                      vm_mod_fused_nn_conv2d_1 |            - |              - |      0 |
# |   13 |                         vm_mod_fused_nn_conv2d_add_nn_relu_14 |            - |              - |      0 |
# |   14 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_1 |            - |              - |      0 |
# |   15 |                                  vm_mod_fused_nn_conv2d_add_2 |            - |              - |      0 |
# |   16 |                            vm_mod_fused_nn_conv2d_add_nn_relu |            - |              - |      0 |
# |   17 |                          vm_mod_fused_nn_conv2d_add_nn_relu_7 |            - |              - |      0 |
# |   18 |                         vm_mod_fused_nn_conv2d_add_nn_relu_10 |            - |              - |      0 |
# |   19 |               vm_mod_fused_nn_max_pool2d_multiply_add_nn_relu |            - |              - |      0 |
# |   20 |                          vm_mod_fused_nn_conv2d_add_nn_relu_3 |            - |              - |      0 |
# |   21 |                         vm_mod_fused_nn_conv2d_add_nn_relu_15 |            - |              - |      0 |
# |   22 |               vm_mod_fused_nn_conv2d_add_multiply_add_nn_relu |            - |              - |      0 |
# |   23 |                         vm_mod_fused_nn_conv2d_add_nn_relu_11 |            - |              - |      0 |
# |   24 |                                  vm_mod_fused_nn_conv2d_add_1 |            - |              - |      0 |
# |   25 |                                      vm_mod_fused_nn_conv2d_2 |            - |              - |      0 |
# |   26 |                          vm_mod_fused_nn_conv2d_add_nn_relu_6 |            - |              - |      0 |
# |   27 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_2 |            - |              - |      0 |
# |   28 |                          vm_mod_fused_nn_conv2d_add_nn_relu_2 |            - |              - |      0 |
# |   29 |                          vm_mod_fused_nn_conv2d_add_nn_relu_9 |            - |              - |      0 |
# |   30 |                         vm_mod_fused_nn_conv2d_add_nn_relu_12 |            - |              - |      0 |
# -----------------------------------------------------------------------------------------------------------------
# Estimated total latency: - ms	Trials: 128	Used time : 546 s	Next ID: 3
# ----------------------------------------------------------------------
# ------------------------------  [ Search ]
# ----------------------------------------------------------------------
# Generate Sketches		#s: 1
# Sample Initial Population	#s: 162	fail_ct: 1886	Time elapsed: 3.57
# GA Iter: 0	Max score: 0.9998	Min score: 0.2346	#Pop: 128	#M+: 0	#M-: 0
# GA Iter: 4	Max score: 0.9998	Min score: 0.9821	#Pop: 128	#M+: 1386	#M-: 0
# EvolutionarySearch		#s: 128	Time elapsed: 45.38
# ----------------------------------------------------------------------
# ------------------------------  [ Measure ]
# ----------------------------------------------------------------------
# Get 64 programs to measure:
# ............T***********
# ............************
# ............************
# ............************
# ............************
# ....****
# Time elapsed for measurement: 220.86 s
# ----------------------------------------------------------------------
# ------------------------------  [ Train cost model ]
# ----------------------------------------------------------------------
# Time elapsed for training: 0.51 s
# ----------------------------------------------------------------------
# ------------------------------  [ Task Scheduler ]
# ----------------------------------------------------------------------
# |  ID  |                       Task Description                        | Latency (ms) | Speed (GFLOPS) | Trials |
# -----------------------------------------------------------------------------------------------------------------
# |    0 |                          vm_mod_fused_nn_conv2d_add_nn_relu_5 |        0.251 |         922.61 |     64 |
# |    1 |                                    vm_mod_fused_nn_conv2d_add |        0.138 |         751.82 |     64 |
# |    2 |                                        vm_mod_fused_nn_conv2d |        0.086 |        1189.30 |     64 |
# |    3 |                          vm_mod_fused_nn_conv2d_add_nn_relu_1 |        0.029 |         912.46 |     64 |
# |    4 |                                     vm_mod_fused_nn_dense_add |            - |              - |      0 |
# |    5 |                         vm_mod_fused_nn_conv2d_add_nn_relu_13 |            - |              - |      0 |
# |    6 |                                  vm_mod_fused_nn_conv2d_add_3 |            - |              - |      0 |
# |    7 |                             vm_mod_fused_nn_global_avg_pool2d |            - |              - |      0 |
# |    8 |                          vm_mod_fused_nn_conv2d_add_nn_relu_8 |            - |              - |      0 |
# |    9 |                        vm_mod_fused_nn_conv2d_add_add_nn_relu |            - |              - |      0 |
# |   10 |                                      vm_mod_fused_nn_conv2d_3 |            - |              - |      0 |
# |   11 |                          vm_mod_fused_nn_conv2d_add_nn_relu_4 |            - |              - |      0 |
# |   12 |                                      vm_mod_fused_nn_conv2d_1 |            - |              - |      0 |
# |   13 |                         vm_mod_fused_nn_conv2d_add_nn_relu_14 |            - |              - |      0 |
# |   14 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_1 |            - |              - |      0 |
# |   15 |                                  vm_mod_fused_nn_conv2d_add_2 |            - |              - |      0 |
# |   16 |                            vm_mod_fused_nn_conv2d_add_nn_relu |            - |              - |      0 |
# |   17 |                          vm_mod_fused_nn_conv2d_add_nn_relu_7 |            - |              - |      0 |
# |   18 |                         vm_mod_fused_nn_conv2d_add_nn_relu_10 |            - |              - |      0 |
# |   19 |               vm_mod_fused_nn_max_pool2d_multiply_add_nn_relu |            - |              - |      0 |
# |   20 |                          vm_mod_fused_nn_conv2d_add_nn_relu_3 |            - |              - |      0 |
# |   21 |                         vm_mod_fused_nn_conv2d_add_nn_relu_15 |            - |              - |      0 |
# |   22 |               vm_mod_fused_nn_conv2d_add_multiply_add_nn_relu |            - |              - |      0 |
# |   23 |                         vm_mod_fused_nn_conv2d_add_nn_relu_11 |            - |              - |      0 |
# |   24 |                                  vm_mod_fused_nn_conv2d_add_1 |            - |              - |      0 |
# |   25 |                                      vm_mod_fused_nn_conv2d_2 |            - |              - |      0 |
# |   26 |                          vm_mod_fused_nn_conv2d_add_nn_relu_6 |            - |              - |      0 |
# |   27 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_2 |            - |              - |      0 |
# |   28 |                          vm_mod_fused_nn_conv2d_add_nn_relu_2 |            - |              - |      0 |
# |   29 |                          vm_mod_fused_nn_conv2d_add_nn_relu_9 |            - |              - |      0 |
# |   30 |                         vm_mod_fused_nn_conv2d_add_nn_relu_12 |            - |              - |      0 |
# -----------------------------------------------------------------------------------------------------------------
# Estimated total latency: - ms	Trials: 192	Used time : 816 s	Next ID: 4
# ----------------------------------------------------------------------
# ------------------------------  [ Search ]
# ----------------------------------------------------------------------
# Generate Sketches		#s: 2
# Sample Initial Population	#s: 61	fail_ct: 6083	Time elapsed: 7.36
# GA Iter: 0	Max score: 0.9939	Min score: 0.0014	#Pop: 61	#M+: 0	#M-: 0
# GA Iter: 4	Max score: 0.9999	Min score: 0.9768	#Pop: 128	#M+: 1383	#M-: 0
# EvolutionarySearch		#s: 128	Time elapsed: 20.21
# ----------------------------------------------------------------------
# ------------------------------  [ Measure ]
# ----------------------------------------------------------------------
# Get 64 programs to measure:
# ............*****E*******
# ............************
# ............************
# ............************
# ............************
# ....****
# Time elapsed for measurement: 180.88 s
# ----------------------------------------------------------------------
# ------------------------------  [ Train cost model ]
# ----------------------------------------------------------------------
# Time elapsed for training: 0.33 s
# ----------------------------------------------------------------------
# ------------------------------  [ Task Scheduler ]
# |  ID  |                       Task Description                        | Latency (ms) | Speed (GFLOPS) | Trials |
# -----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------
# |    0 |                          vm_mod_fused_nn_conv2d_add_nn_relu_5 |        0.251 |         922.61 |     64 |
# |    1 |                                    vm_mod_fused_nn_conv2d_add |        0.138 |         751.82 |     64 |
# |    2 |                                        vm_mod_fused_nn_conv2d |        0.086 |        1189.30 |     64 |
# |    3 |                          vm_mod_fused_nn_conv2d_add_nn_relu_1 |        0.029 |         912.46 |     64 |
# |    4 |                                     vm_mod_fused_nn_dense_add |        0.055 |          75.17 |     64 |
# |    5 |                         vm_mod_fused_nn_conv2d_add_nn_relu_13 |            - |              - |      0 |
# |    6 |                                  vm_mod_fused_nn_conv2d_add_3 |            - |              - |      0 |
# |    7 |                             vm_mod_fused_nn_global_avg_pool2d |            - |              - |      0 |
# |    8 |                          vm_mod_fused_nn_conv2d_add_nn_relu_8 |            - |              - |      0 |
# |    9 |                        vm_mod_fused_nn_conv2d_add_add_nn_relu |            - |              - |      0 |
# |   10 |                                      vm_mod_fused_nn_conv2d_3 |            - |              - |      0 |
# |   11 |                          vm_mod_fused_nn_conv2d_add_nn_relu_4 |            - |              - |      0 |
# |   12 |                                      vm_mod_fused_nn_conv2d_1 |            - |              - |      0 |
# |   13 |                         vm_mod_fused_nn_conv2d_add_nn_relu_14 |            - |              - |      0 |
# |   14 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_1 |            - |              - |      0 |
# |   15 |                                  vm_mod_fused_nn_conv2d_add_2 |            - |              - |      0 |
# |   16 |                            vm_mod_fused_nn_conv2d_add_nn_relu |            - |              - |      0 |
# |   17 |                          vm_mod_fused_nn_conv2d_add_nn_relu_7 |            - |              - |      0 |
# |   18 |                         vm_mod_fused_nn_conv2d_add_nn_relu_10 |            - |              - |      0 |
# |   19 |               vm_mod_fused_nn_max_pool2d_multiply_add_nn_relu |            - |              - |      0 |
# |   20 |                          vm_mod_fused_nn_conv2d_add_nn_relu_3 |            - |              - |      0 |
# |   21 |                         vm_mod_fused_nn_conv2d_add_nn_relu_15 |            - |              - |      0 |
# |   22 |               vm_mod_fused_nn_conv2d_add_multiply_add_nn_relu |            - |              - |      0 |
# |   23 |                         vm_mod_fused_nn_conv2d_add_nn_relu_11 |            - |              - |      0 |
# |   24 |                                  vm_mod_fused_nn_conv2d_add_1 |            - |              - |      0 |
# |   25 |                                      vm_mod_fused_nn_conv2d_2 |            - |              - |      0 |
# |   26 |                          vm_mod_fused_nn_conv2d_add_nn_relu_6 |            - |              - |      0 |
# |   27 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_2 |            - |              - |      0 |
# |   28 |                          vm_mod_fused_nn_conv2d_add_nn_relu_2 |            - |              - |      0 |
# |   29 |                          vm_mod_fused_nn_conv2d_add_nn_relu_9 |            - |              - |      0 |
# |   30 |                         vm_mod_fused_nn_conv2d_add_nn_relu_12 |            - |              - |      0 |
# -----------------------------------------------------------------------------------------------------------------
# Estimated total latency: - ms	Trials: 256	Used time : 1025 s	Next ID: 5
# ----------------------------------------------------------------------
# ------------------------------  [ Search ]
# ----------------------------------------------------------------------
# Generate Sketches		#s: 1
# Sample Initial Population	#s: 72	fail_ct: 1976	Time elapsed: 3.70
# GA Iter: 0	Max score: 0.9939	Min score: 0.0094	#Pop: 72	#M+: 0	#M-: 0
# GA Iter: 4	Max score: 0.9998	Min score: 0.9824	#Pop: 128	#M+: 1392	#M-: 0
# EvolutionarySearch		#s: 128	Time elapsed: 61.53
# ----------------------------------------------------------------------
# ------------------------------  [ Measure ]
# ----------------------------------------------------------------------
# Get 64 programs to measure:
# ............************
# ............************
# ............************
# ............***********E*
# ............************
# ....*E***
# Time elapsed for measurement: 193.38 s
# ----------------------------------------------------------------------
# ------------------------------  [ Train cost model ]
# ----------------------------------------------------------------------
# Time elapsed for training: 0.53 s
# |  ID  |                       Task Description                        | Latency (ms) | Speed (GFLOPS) | Trials |
# -----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------
# ------------------------------  [ Task Scheduler ]
# ----------------------------------------------------------------------
# |    0 |                          vm_mod_fused_nn_conv2d_add_nn_relu_5 |        0.251 |         922.61 |     64 |
# |    1 |                                    vm_mod_fused_nn_conv2d_add |        0.138 |         751.82 |     64 |
# |    2 |                                        vm_mod_fused_nn_conv2d |        0.086 |        1189.30 |     64 |
# |    3 |                          vm_mod_fused_nn_conv2d_add_nn_relu_1 |        0.029 |         912.46 |     64 |
# |    4 |                                     vm_mod_fused_nn_dense_add |        0.055 |          75.17 |     64 |
# |    5 |                         vm_mod_fused_nn_conv2d_add_nn_relu_13 |        0.605 |         382.12 |     64 |
# |    6 |                                  vm_mod_fused_nn_conv2d_add_3 |            - |              - |      0 |
# |    7 |                             vm_mod_fused_nn_global_avg_pool2d |            - |              - |      0 |
# |    8 |                          vm_mod_fused_nn_conv2d_add_nn_relu_8 |            - |              - |      0 |
# |    9 |                        vm_mod_fused_nn_conv2d_add_add_nn_relu |            - |              - |      0 |
# |   10 |                                      vm_mod_fused_nn_conv2d_3 |            - |              - |      0 |
# |   11 |                          vm_mod_fused_nn_conv2d_add_nn_relu_4 |            - |              - |      0 |
# |   12 |                                      vm_mod_fused_nn_conv2d_1 |            - |              - |      0 |
# |   13 |                         vm_mod_fused_nn_conv2d_add_nn_relu_14 |            - |              - |      0 |
# |   14 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_1 |            - |              - |      0 |
# |   15 |                                  vm_mod_fused_nn_conv2d_add_2 |            - |              - |      0 |
# |   16 |                            vm_mod_fused_nn_conv2d_add_nn_relu |            - |              - |      0 |
# |   17 |                          vm_mod_fused_nn_conv2d_add_nn_relu_7 |            - |              - |      0 |
# |   18 |                         vm_mod_fused_nn_conv2d_add_nn_relu_10 |            - |              - |      0 |
# |   19 |               vm_mod_fused_nn_max_pool2d_multiply_add_nn_relu |            - |              - |      0 |
# |   20 |                          vm_mod_fused_nn_conv2d_add_nn_relu_3 |            - |              - |      0 |
# |   21 |                         vm_mod_fused_nn_conv2d_add_nn_relu_15 |            - |              - |      0 |
# |   22 |               vm_mod_fused_nn_conv2d_add_multiply_add_nn_relu |            - |              - |      0 |
# |   23 |                         vm_mod_fused_nn_conv2d_add_nn_relu_11 |            - |              - |      0 |
# |   24 |                                  vm_mod_fused_nn_conv2d_add_1 |            - |              - |      0 |
# |   25 |                                      vm_mod_fused_nn_conv2d_2 |            - |              - |      0 |
# |   26 |                          vm_mod_fused_nn_conv2d_add_nn_relu_6 |            - |              - |      0 |
# |   27 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_2 |            - |              - |      0 |
# |   28 |                          vm_mod_fused_nn_conv2d_add_nn_relu_2 |            - |              - |      0 |
# |   29 |                          vm_mod_fused_nn_conv2d_add_nn_relu_9 |            - |              - |      0 |
# |   30 |                         vm_mod_fused_nn_conv2d_add_nn_relu_12 |            - |              - |      0 |
# -----------------------------------------------------------------------------------------------------------------
# Estimated total latency: - ms	Trials: 320	Used time : 1284 s	Next ID: 6
# ----------------------------------------------------------------------
# ------------------------------  [ Search ]
# ----------------------------------------------------------------------
# Generate Sketches		#s: 1
# Sample Initial Population	#s: 117	fail_ct: 1931	Time elapsed: 3.40
# GA Iter: 0	Max score: 0.9912	Min score: 0.0309	#Pop: 117	#M+: 0	#M-: 0
# GA Iter: 4	Max score: 0.9994	Min score: 0.9781	#Pop: 128	#M+: 1377	#M-: 0
# EvolutionarySearch		#s: 128	Time elapsed: 44.30
# ----------------------------------------------------------------------
# ------------------------------  [ Measure ]
# ----------------------------------------------------------------------
# Get 64 programs to measure:
# ............************
# ............************E
# ............************
# ............*******E***E**
# ............************
# ....****
# Time elapsed for measurement: 210.44 s
# ----------------------------------------------------------------------
# ------------------------------  [ Train cost model ]
# ----------------------------------------------------------------------
# Time elapsed for training: 0.60 s
# ----------------------------------------------------------------------
# ------------------------------  [ Task Scheduler ]
# |  ID  |                       Task Description                        | Latency (ms) | Speed (GFLOPS) | Trials |
# -----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------
# |    0 |                          vm_mod_fused_nn_conv2d_add_nn_relu_5 |        0.251 |         922.61 |     64 |
# |    1 |                                    vm_mod_fused_nn_conv2d_add |        0.138 |         751.82 |     64 |
# |    2 |                                        vm_mod_fused_nn_conv2d |        0.086 |        1189.30 |     64 |
# |    3 |                          vm_mod_fused_nn_conv2d_add_nn_relu_1 |        0.029 |         912.46 |     64 |
# |    4 |                                     vm_mod_fused_nn_dense_add |        0.055 |          75.17 |     64 |
# |    5 |                         vm_mod_fused_nn_conv2d_add_nn_relu_13 |        0.605 |         382.12 |     64 |
# |    6 |                                  vm_mod_fused_nn_conv2d_add_3 |        0.143 |         720.98 |     64 |
# |    7 |                             vm_mod_fused_nn_global_avg_pool2d |            - |              - |      0 |
# |    8 |                          vm_mod_fused_nn_conv2d_add_nn_relu_8 |            - |              - |      0 |
# |    9 |                        vm_mod_fused_nn_conv2d_add_add_nn_relu |            - |              - |      0 |
# |   10 |                                      vm_mod_fused_nn_conv2d_3 |            - |              - |      0 |
# |   11 |                          vm_mod_fused_nn_conv2d_add_nn_relu_4 |            - |              - |      0 |
# |   12 |                                      vm_mod_fused_nn_conv2d_1 |            - |              - |      0 |
# |   13 |                         vm_mod_fused_nn_conv2d_add_nn_relu_14 |            - |              - |      0 |
# |   14 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_1 |            - |              - |      0 |
# |   15 |                                  vm_mod_fused_nn_conv2d_add_2 |            - |              - |      0 |
# |   16 |                            vm_mod_fused_nn_conv2d_add_nn_relu |            - |              - |      0 |
# |   17 |                          vm_mod_fused_nn_conv2d_add_nn_relu_7 |            - |              - |      0 |
# |   18 |                         vm_mod_fused_nn_conv2d_add_nn_relu_10 |            - |              - |      0 |
# |   19 |               vm_mod_fused_nn_max_pool2d_multiply_add_nn_relu |            - |              - |      0 |
# |   20 |                          vm_mod_fused_nn_conv2d_add_nn_relu_3 |            - |              - |      0 |
# |   21 |                         vm_mod_fused_nn_conv2d_add_nn_relu_15 |            - |              - |      0 |
# |   22 |               vm_mod_fused_nn_conv2d_add_multiply_add_nn_relu |            - |              - |      0 |
# |   23 |                         vm_mod_fused_nn_conv2d_add_nn_relu_11 |            - |              - |      0 |
# |   24 |                                  vm_mod_fused_nn_conv2d_add_1 |            - |              - |      0 |
# |   25 |                                      vm_mod_fused_nn_conv2d_2 |            - |              - |      0 |
# |   26 |                          vm_mod_fused_nn_conv2d_add_nn_relu_6 |            - |              - |      0 |
# |   27 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_2 |            - |              - |      0 |
# |   28 |                          vm_mod_fused_nn_conv2d_add_nn_relu_2 |            - |              - |      0 |
# |   29 |                          vm_mod_fused_nn_conv2d_add_nn_relu_9 |            - |              - |      0 |
# |   30 |                         vm_mod_fused_nn_conv2d_add_nn_relu_12 |            - |              - |      0 |
# -----------------------------------------------------------------------------------------------------------------
# Estimated total latency: - ms	Trials: 384	Used time : 1543 s	Next ID: 7
# ----------------------------------------------------------------------
# ------------------------------  [ Search ]
# ----------------------------------------------------------------------
# Generate Sketches		#s: 1
# Sample Iter: 5	#Pop: 5	#Target: 50	fail_ct: 10235	Time elapsed: 9.79
# #Target has been reduced to 25 due to too many failures or duplications
# Sample Iter: 10	#Pop: 5	#Target: 25	fail_ct: 20475	Time elapsed: 19.61
# #Target has been reduced to 12 due to too many failures or duplications
# Sample Iter: 15	#Pop: 5	#Target: 12	fail_ct: 30715	Time elapsed: 29.25
# #Target has been reduced to 6 due to too many failures or duplications
# Sample Iter: 20	#Pop: 5	#Target: 6	fail_ct: 40955	Time elapsed: 38.74
# #Target has been reduced to 3 due to too many failures or duplications
# Sample Initial Population	#s: 5	fail_ct: 43003	Time elapsed: 40.59
# GA Iter: 0	Max score: 0.7805	Min score: 0.0759	#Pop: 5	#M+: 0	#M-: 0
# GA Iter: 4	Max score: 0.9995	Min score: 0.9255	#Pop: 128	#M+: 1384	#M-: 0
# EvolutionarySearch		#s: 128	Time elapsed: 6.60
# ----------------------------------------------------------------------
# ------------------------------  [ Measure ]
# ----------------------------------------------------------------------
# Get 64 programs to measure:
# ............************
# ............************
# ............************
# ............************
# ............************
# ....****
# Time elapsed for measurement: 144.75 s
# ----------------------------------------------------------------------
# ------------------------------  [ Train cost model ]
# ----------------------------------------------------------------------
# Time elapsed for training: 0.29 s
# |  ID  |                       Task Description                        | Latency (ms) | Speed (GFLOPS) | Trials |
# -----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------
# ------------------------------  [ Task Scheduler ]
# ----------------------------------------------------------------------
# |    0 |                          vm_mod_fused_nn_conv2d_add_nn_relu_5 |        0.251 |         922.61 |     64 |
# |    1 |                                    vm_mod_fused_nn_conv2d_add |        0.138 |         751.82 |     64 |
# |    2 |                                        vm_mod_fused_nn_conv2d |        0.086 |        1189.30 |     64 |
# |    3 |                          vm_mod_fused_nn_conv2d_add_nn_relu_1 |        0.029 |         912.46 |     64 |
# |    4 |                                     vm_mod_fused_nn_dense_add |        0.055 |          75.17 |     64 |
# |    5 |                         vm_mod_fused_nn_conv2d_add_nn_relu_13 |        0.605 |         382.12 |     64 |
# |    6 |                                  vm_mod_fused_nn_conv2d_add_3 |        0.143 |         720.98 |     64 |
# |    7 |                             vm_mod_fused_nn_global_avg_pool2d |        0.016 |          -0.00 |     64 |
# |    8 |                          vm_mod_fused_nn_conv2d_add_nn_relu_8 |            - |              - |      0 |
# |    9 |                        vm_mod_fused_nn_conv2d_add_add_nn_relu |            - |              - |      0 |
# |   10 |                                      vm_mod_fused_nn_conv2d_3 |            - |              - |      0 |
# |   11 |                          vm_mod_fused_nn_conv2d_add_nn_relu_4 |            - |              - |      0 |
# |   12 |                                      vm_mod_fused_nn_conv2d_1 |            - |              - |      0 |
# |   13 |                         vm_mod_fused_nn_conv2d_add_nn_relu_14 |            - |              - |      0 |
# |   14 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_1 |            - |              - |      0 |
# |   15 |                                  vm_mod_fused_nn_conv2d_add_2 |            - |              - |      0 |
# |   16 |                            vm_mod_fused_nn_conv2d_add_nn_relu |            - |              - |      0 |
# |   17 |                          vm_mod_fused_nn_conv2d_add_nn_relu_7 |            - |              - |      0 |
# |   18 |                         vm_mod_fused_nn_conv2d_add_nn_relu_10 |            - |              - |      0 |
# |   19 |               vm_mod_fused_nn_max_pool2d_multiply_add_nn_relu |            - |              - |      0 |
# |   20 |                          vm_mod_fused_nn_conv2d_add_nn_relu_3 |            - |              - |      0 |
# |   21 |                         vm_mod_fused_nn_conv2d_add_nn_relu_15 |            - |              - |      0 |
# |   22 |               vm_mod_fused_nn_conv2d_add_multiply_add_nn_relu |            - |              - |      0 |
# |   23 |                         vm_mod_fused_nn_conv2d_add_nn_relu_11 |            - |              - |      0 |
# |   24 |                                  vm_mod_fused_nn_conv2d_add_1 |            - |              - |      0 |
# |   25 |                                      vm_mod_fused_nn_conv2d_2 |            - |              - |      0 |
# |   26 |                          vm_mod_fused_nn_conv2d_add_nn_relu_6 |            - |              - |      0 |
# |   27 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_2 |            - |              - |      0 |
# |   28 |                          vm_mod_fused_nn_conv2d_add_nn_relu_2 |            - |              - |      0 |
# |   29 |                          vm_mod_fused_nn_conv2d_add_nn_relu_9 |            - |              - |      0 |
# |   30 |                         vm_mod_fused_nn_conv2d_add_nn_relu_12 |            - |              - |      0 |
# -----------------------------------------------------------------------------------------------------------------
# Estimated total latency: - ms	Trials: 448	Used time : 1735 s	Next ID: 8
# ----------------------------------------------------------------------
# ------------------------------  [ Search ]
# ----------------------------------------------------------------------
# Generate Sketches		#s: 1
# Sample Initial Population	#s: 122	fail_ct: 1926	Time elapsed: 3.24
# GA Iter: 0	Max score: 0.9884	Min score: 0.0087	#Pop: 122	#M+: 0	#M-: 0

# %%
# tune again if possible some error about

# %%
# recmpile with the tuned parameters
#tvmc.compile(model, target='llvm', tuning_records='records.log')
tvmc.compile(model, target='cuda', tuning_records=log_file)

# %% [markdown]
# ## Save and then start the process in the terminal:
#
# ```python
# python my_tvmc_script.py
# ```
# Note: Your fans may become very active

# %% [markdown]
# ## Example results:
#
# ```python
# Time elapsed for training: 18.99 s
# Execution time summary:
# mean (ms)   max (ms)   min (ms)   std (ms)
#   25.24      26.12      24.89       0.38
#
#
# Output Names:
# ['output_0']
# ```

# %% [markdown]
# ## Additional TVMC Functionalities

# %% [markdown]
# ## Saving the model
#
# To make things faster for later, after loading the model (Step 1) save the Relay version.
# The model will then appear where you saved it for later in the coverted syntax.
#
# ```python
# model = tvmc.load('my_model.onnx') #Step 1: Load
# model.save(desired_model_path)
# ```

# %% [markdown]
# ## Saving the package
#
# After the model has been compiled (Step 2) the package also is also saveable.
#
# ```python
# tvmc.compile(model, target="llvm", package_path="whatever") #Step 2: Compile
#
# new_package = tvmc.TVMCPackage(package_path="whatever")
# result = tvmc.run(new_package, device="cpu") #Step 3: Run
# ```

# %% [markdown]
# ## Using Autoscheduler
#
# Use the next generation of tvm to enable potentially faster run speed results.
# The search space of the schedules is automatically generated unlike
# previously where they needed to be hand written. (Learn more:
# [1](https://tvm.apache.org/2021/03/03/intro-auto-scheduler),
# [2](https://arxiv.org/abs/2006.06762))
#
# ```python
# tvmc.tune(model, target="llvm", enable_autoscheduler = True)
# ```

# %% [markdown]
# ## Saving the tuning results
#
# The tuning results can be saved in a file for later reuse.
#
# Method 1:
# ```python
# log_file = "hello.json"
#
# # Run tuning
# tvmc.tune(model, target="llvm", tuning_records=log_file)
#
# ...
#
# # Later run tuning and reuse tuning results
# tvmc.tune(model, target="llvm", prior_records=log_file)
# ```
# Method 2:
# ```python
# # Run tuning
# tuning_records = tvmc.tune(model, target="llvm")
#
# ...
#
# # Later run tuning and reuse tuning results
# tvmc.tune(model, target="llvm", prior_records=tuning_records)
# ```

# %% [markdown]
# ## Tuning a more complex model:
#
# If you notice T's printing that look like ``.........T.T..T..T..T.T.T.T.T.T.``
# increase the searching time frame:
#
# ```python
# tvmc.tune(model,trials=10000,timeout=10,)
# ```

# %% [markdown]
# ## Compiling a model for a remote device:
#
# A remote procedural call (RPC) is useful when you would like to compile for hardware
# that is not on your local machine. The tvmc methods support this.
# To set up the RPC server take a look at the 'Set up RPC Server on Device'
# section in this [document](https://tvm.apache.org/docs/tutorials/get_started/cross_compilation_and_rpc.html).
#
# Within the TVMC Script include the following and adjust accordingly:
#
# ```python
# tvmc.tune(
#      model,
#      target=target, # Compilation target as string // Device to compile for
#      target_host=target_host, # Host processor
#      hostname=host_ip_address, # The IP address of an RPC tracker, used when benchmarking remotely.
#      port=port_number, # The port of the RPC tracker to connect to. Defaults to 9090.
#      rpc_key=your_key, # The RPC tracker key of the target device. Required when rpc_tracker is provided
# )
# ```
